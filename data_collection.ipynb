# %% [markdown]
# ## Loading API Key

# %%
import os
from dotenv import load_dotenv

load_dotenv()
key = os.getenv("API_KEY")

# %% [markdown]
# ## Imports

# %%
import requests
import pandas as pd
import json
from concurrent.futures import ThreadPoolExecutor, as_completed
import time
import requests
from itertools import islice

# %% [markdown]
# ## Function Definitions

# %%
def read_clans_range(file_name="clans_list.txt", start=0, end=100):
    with open(file_name, "r") as f:
        # Use islice for efficient range reading
        clans = list(islice(f, start, end))
    # Strip whitespace and return as a list of strings
    return [clan.strip() for clan in clans]


def get_clans_file(limit=100, minmembers=50, maxmembers=50, minscore=1000, key="", max_clans=3000, output_file="clans_list.txt"):
    all_clans = []
    after = None
    
    while len(all_clans) < max_clans:
        # Build the base URL
        url = f"https://api.clashroyale.com/v1/clans?minMembers={minmembers}&maxMembers={maxmembers}&minScore={minscore}&limit={limit}"
        
        # Add the 'after' marker if present
        if after:
            url += f"&after={after}"
        
        # Make the API call
        headers = {"Authorization": f"Bearer {key}"}
        response = requests.get(url, headers=headers)
        
        if response.status_code == 200:
            data = response.json()
            clans = data.get("items", [])
            paging = data.get("paging", {})
            
            # Add the clans to the master list
            all_clans.extend(clan["tag"] for clan in clans)
            
            # Get the next 'after' marker
            after = paging.get("cursors", {}).get("after")
            
            # Stop if there are no more pages
            if not after:
                print("Reached the last page.")
                break
            
            print(f"Retrieved {len(all_clans)} total clans so far...")
        
        else:
            print(f"Error retrieving clans: {response.status_code} - {response.text}")
            break
    
    # Save the clans to a file
    with open(output_file, "w") as f:
        for clan in all_clans[:max_clans]:
            f.write(clan + "\n")
    
    print(f"Saved {len(all_clans[:max_clans])} clans to {output_file}")

def call_api(url, key, verbose = 0):
    headers = {
        "Authorization": f"Bearer {key}"
    }
    response = requests.get(url, headers=headers)
    if response.status_code == 200 and verbose > 0:
        print("Success!")
    elif verbose > 0:
        print(f"Error: {response.status_code}")
    return response

def battles_to_dataframe(battles, acceptable_types = ["PvP", "pathOfLegend"]):
    rows = []
    for battle in battles:
        if battle['type'] in acceptable_types:
            player_won = battle["team"][0]["crowns"] > battle["opponent"][0]["crowns"]
            winlose = ["team", "opponent"] if player_won else ["opponent", "team"]
            row = {
                "battleTime": battle["battleTime"],
                "battleType": battle["type"],
                "battleMode": battle["gameMode"]["name"],
                "arena": battle["arena"]["id"],
                "winner": battle[winlose[0]][0]["tag"],
                "loser": battle[winlose[1]][0]["tag"],
            }
            labels = ['winner', 'loser']
            for k in range(2):
                for i, player in enumerate(battle[winlose[k]]):
                    for j, card in enumerate(player["cards"]):
                        row[f"{labels[k]}_card_{j+1}_id"] = card["id"]
                        row[f"{labels[k]}_card_{j+1}_level"] = card["level"]
                    tower_card = player["supportCards"][0]
                    row[f"{labels[k]}_tower_card_id"] = tower_card["id"]
                    row[f"{labels[k]}_tower_card_level"] = tower_card["level"]
            
            rows.append(row)
    
    df = pd.DataFrame(rows)
    id_cols = [col for col in df.columns if "_id" in col]
    level_cols = [col for col in df.columns if "_level" in col]
    df[id_cols] = df[id_cols].astype("int32")
    df[level_cols] = df[level_cols].astype("int8")
    
    return df

def get_player_battles(player_id, key):
    if player_id.startswith("#"):
        player_id = player_id[1:]
    url = f"https://api.clashroyale.com/v1/players/%23{player_id}/battlelog"
    return battles_to_dataframe(call_api(url, key).json())

def get_clans(limit = 100, minmembers = 50, minscore = 1000, key = key):
    clan_url = f"https://api.clashroyale.com/v1/clans?minMembers={minmembers}&minScore={minscore}&limit={limit}"
    clan_json = call_api(clan_url, key)
    clans = [i["tag"] for i in clan_json.json()["items"]]
    return clans

def get_members_from_clan(clan, key):
    members_url = f"https://api.clashroyale.com/v1/clans/%23{clan[1:]}/members"
    members_json = call_api(members_url, key)
    members = [i["tag"] for i in members_json.json()["items"]]
    return members

def get_full(file_name, num_clans = 100, key = key, clans_list = None, max_workers = 1):
    if not clans_list:
        clans = get_clans(num_clans, key=key)
    else:
        clans = clans_list
    print(f"Retrieved {len(clans)} clans")
    pd
    players = []
    for c in clans:
        players += get_members_from_clan(c, key)
    players = list(set(players))
    print(f"Retrieved {len(players)} players")
    if max_workers == 1:
        df = get_battles_sequential(players, key, file_name)
    else:
        df = get_battles_parallel(players, key, file_name, max_workers)
    df.to_csv(f"{file_name}.csv", index=False)
    print(f"Saved final df to {file_name}.csv")
    print("Done!")
    return df

def get_battles_sequential(players, key, file_name):
    df = pd.DataFrame()
    for p in range(len(players)):
        print(f"Retrieving battles for player {p}/{len(players)}     ", end="\r")
        try:
            player_df = get_player_battles(players[p], key)
            df = pd.concat([df, player_df])
        except Exception as e:
            print(f"Error retrieving battles for player {p}: {e}")
        if p + 1 %100 == 0:
            df.to_csv(f"{file_name}.csv", index=False)
            print(f"Saved {p} players to {file_name}.csv", end = "\r")
    print(f"Retrieving battles for player {p + 1}/{len(players)}")
    return df

def get_battles_parallel(players, key, file_name, max_workers):
    df_list = []
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        futures = [executor.submit(get_player_battles, player, key) for player in players]
        for i, future in enumerate(as_completed(futures)):
            try:
                player_df = future.result()
                if not player_df.empty:
                    df_list.append(player_df)
                if (i + 1) % 500 == 0:
                    pd.concat(df_list, ignore_index=True).to_csv(f"{file_name}.csv", index=False)
                    print(f"Saved {i + 1} players to {file_name}.csv", end="\r")
            except Exception as e:
                print(f"Error retrieving battles for player: {e}")
    final_df = pd.concat(df_list, ignore_index=True)
    return final_df

# %% [markdown]
# ## Testing API Key Functionality

# %%
my_id = "ULCYC0UU"
url = f"https://api.clashroyale.com/v1/players/%23{my_id}/battlelog"
url = "https://api.clashroyale.com/v1/clans?maxMembers=30&minMembers=20&minScore=1000&limit=3000"
x = call_api(url, key).json()
x
# Out:
# {'items': [{'tag': '#QG88V992',
#    'name': '#1 SOLO WARRIOR',
#    'type': 'inviteOnly',
#    'badgeId': 16000081,
#    'clanScore': 40441,
#    'clanWarTrophies': 1483,
#    'location': {'id': 57000120,
#     'name': 'Italy',
#     'isCountry': True,
#     'countryCode': 'IT'},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 548,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#R9LR9LLR',
#    'name': '#阳光城市︱南昌',
#    'type': 'open',
#    'badgeId': 16000143,
#    'clanScore': 45454,
#    'clanWarTrophies': 1433,
#    'location': {'id': 57000056,
#     'name': 'China',
#     'isCountry': True,
#     'countryCode': 'CN'},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 2155,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 30},
#   {'tag': '#R0V2R0VC',
#    'name': '#阳光城市︱太原',
#    'type': 'open',
#    'badgeId': 16000143,
#    'clanScore': 25263,
#    'clanWarTrophies': 573,
#    'location': {'id': 57000056,
#     'name': 'China',
#     'isCountry': True,
#     'countryCode': 'CN'},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 152,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 24},
#   {'tag': '#R8VCYVJR',
#    'name': '#阳光城市︱武漢',
#    'type': 'open',
#    'badgeId': 16000143,
#    'clanScore': 10772,
#    'clanWarTrophies': 1252,
#    'location': {'id': 57000056,
#     'name': 'China',
#     'isCountry': True,
#     'countryCode': 'CN'},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 160,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 21},
#   {'tag': '#QGGUV999',
#    'name': '#阳光城市︱济南',
#    'type': 'open',
#    'badgeId': 16000143,
#    'clanScore': 5235,
#    'clanWarTrophies': 639,
#    'location': {'id': 57000056,
#     'name': 'China',
#     'isCountry': True,
#     'countryCode': 'CN'},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 160,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 22},
#   {'tag': '#QQVPP8VP',
#    'name': '#阳光城市︱石家庄',
#    'type': 'open',
#    'badgeId': 16000143,
#    'clanScore': 8063,
#    'clanWarTrophies': 622,
#    'location': {'id': 57000056,
#     'name': 'China',
#     'isCountry': True,
#     'countryCode': 'CN'},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 170,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 23},
#   {'tag': '#QVUJC2J8',
#    'name': '#阳光城市︱石家庄',
#    'type': 'open',
#    'badgeId': 16000143,
#    'clanScore': 2499,
#    'clanWarTrophies': 621,
#    'location': {'id': 57000056,
#     'name': 'China',
#     'isCountry': True,
#     'countryCode': 'CN'},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 199,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 25},
#   {'tag': '#QQLR9GUY',
#    'name': '#阳光城市︱郑州',
#    'type': 'open',
#    'badgeId': 16000143,
#    'clanScore': 21255,
#    'clanWarTrophies': 749,
#    'location': {'id': 57000056,
#     'name': 'China',
#     'isCountry': True,
#     'countryCode': 'CN'},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 188,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 24},
#   {'tag': '#QQYQVUQU',
#    'name': '#阳光城市︱郑州',
#    'type': 'open',
#    'badgeId': 16000143,
#    'clanScore': 20294,
#    'clanWarTrophies': 757,
#    'location': {'id': 57000056,
#     'name': 'China',
#     'isCountry': True,
#     'countryCode': 'CN'},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 198,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 21},
#   {'tag': '#G90LCP0Q',
#    'name': '#阳光城市︱重慶',
#    'type': 'open',
#    'badgeId': 16000143,
#    'clanScore': 19438,
#    'clanWarTrophies': 783,
#    'location': {'id': 57000056,
#     'name': 'China',
#     'isCountry': True,
#     'countryCode': 'CN'},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 113,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 22},
#   {'tag': '#QQ0GYGJ9',
#    'name': '#阳光城市︱重慶',
#    'type': 'open',
#    'badgeId': 16000143,
#    'clanScore': 9828,
#    'clanWarTrophies': 992,
#    'location': {'id': 57000056,
#     'name': 'China',
#     'isCountry': True,
#     'countryCode': 'CN'},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 220,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 26},
#   {'tag': '#QVQR2V02',
#    'name': '#阳光城市︱首︱都',
#    'type': 'open',
#    'badgeId': 16000143,
#    'clanScore': 53900,
#    'clanWarTrophies': 1815,
#    'location': {'id': 57000056,
#     'name': 'China',
#     'isCountry': True,
#     'countryCode': 'CN'},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 2509,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 29},
#   {'tag': '#QGVYUU2G',
#    'name': '#阳光城市︱首︱都',
#    'type': 'open',
#    'badgeId': 16000143,
#    'clanScore': 8455,
#    'clanWarTrophies': 1063,
#    'location': {'id': 57000056,
#     'name': 'China',
#     'isCountry': True,
#     'countryCode': 'CN'},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 140,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 21},
#   {'tag': '#QULURLJV',
#    'name': '*ASC*',
#    'type': 'open',
#    'badgeId': 16000131,
#    'clanScore': 51395,
#    'clanWarTrophies': 1176,
#    'location': {'id': 57000004, 'name': 'Oceania', 'isCountry': False},
#    'requiredTrophies': 2600,
#    'donationsPerWeek': 410,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 22},
#   {'tag': '#L2UGJUJ0',
#    'name': '*Starlight*',
#    'type': 'closed',
#    'badgeId': 16000169,
#    'clanScore': 55064,
#    'clanWarTrophies': 1497,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 1383,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#RYQQ80QQ',
#    'name': '0S CRI0LOS',
#    'type': 'open',
#    'badgeId': 16000075,
#    'clanScore': 48140,
#    'clanWarTrophies': 0,
#    'location': {'id': 57000038,
#     'name': 'Brazil',
#     'isCountry': True,
#     'countryCode': 'BR'},
#    'requiredTrophies': 4000,
#    'donationsPerWeek': 1598,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 24},
#   {'tag': '#Q2YPVLUU',
#    'name': '1-02T',
#    'type': 'open',
#    'badgeId': 16000146,
#    'clanScore': 36825,
#    'clanWarTrophies': 612,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 800,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 22},
#   {'tag': '#Q8JRVQ2L',
#    'name': '1-2바보들',
#    'type': 'open',
#    'badgeId': 16000159,
#    'clanScore': 55345,
#    'clanWarTrophies': 225,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 7500,
#    'donationsPerWeek': 619,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 24},
#   {'tag': '#RY8QRCL0',
#    'name': '1-풀8기 내성발톱들',
#    'type': 'open',
#    'badgeId': 16000170,
#    'clanScore': 45946,
#    'clanWarTrophies': 120,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 603,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#QCCPQCG9',
#    'name': '10R',
#    'type': 'open',
#    'badgeId': 16000126,
#    'clanScore': 38737,
#    'clanWarTrophies': 110,
#    'location': {'id': 57000003, 'name': 'Asia', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 1576,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 21},
#   {'tag': '#GQLRYCRU',
#    'name': '11E',
#    'type': 'inviteOnly',
#    'badgeId': 16000072,
#    'clanScore': 57098,
#    'clanWarTrophies': 160,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 2272,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 21},
#   {'tag': '#G9JG0QVR',
#    'name': '11Бэ',
#    'type': 'open',
#    'badgeId': 16000072,
#    'clanScore': 54528,
#    'clanWarTrophies': 405,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 4000,
#    'donationsPerWeek': 1736,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 21},
#   {'tag': '#9PV2GY0',
#    'name': '1714 Cat',
#    'type': 'inviteOnly',
#    'badgeId': 16000061,
#    'clanScore': 49115,
#    'clanWarTrophies': 2971,
#    'location': {'id': 57000159,
#     'name': 'Montserrat',
#     'isCountry': True,
#     'countryCode': 'MS'},
#    'requiredTrophies': 4000,
#    'donationsPerWeek': 714,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 21},
#   {'tag': '#G0LGCQ',
#    'name': '1905RepKrynecka',
#    'type': 'closed',
#    'badgeId': 16000033,
#    'clanScore': 57677,
#    'clanWarTrophies': 1796,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 710,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#RQR00JQ9',
#    'name': '1H Ferraris',
#    'type': 'inviteOnly',
#    'badgeId': 16000016,
#    'clanScore': 34009,
#    'clanWarTrophies': 70,
#    'location': {'id': 57000000, 'name': 'Europe', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 410,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#GG0ULYPC',
#    'name': '2 B iti',
#    'type': 'open',
#    'badgeId': 16000004,
#    'clanScore': 43805,
#    'clanWarTrophies': 245,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 382,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 21},
#   {'tag': '#R2Y29J90',
#    'name': '2 contra 2',
#    'type': 'open',
#    'badgeId': 16000121,
#    'clanScore': 44289,
#    'clanWarTrophies': 0,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 591,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#QCVVLRQ0',
#    'name': '2026 서울대',
#    'type': 'open',
#    'badgeId': 16000144,
#    'clanScore': 42024,
#    'clanWarTrophies': 12,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 1333,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#QCYUGQJ0',
#    'name': '24-эуд-1',
#    'type': 'open',
#    'badgeId': 16000029,
#    'clanScore': 47703,
#    'clanWarTrophies': 150,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 2300,
#    'donationsPerWeek': 1167,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 23},
#   {'tag': '#QVJV22YP',
#    'name': '28座大王',
#    'type': 'open',
#    'badgeId': 16000046,
#    'clanScore': 46899,
#    'clanWarTrophies': 30,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 1068,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#QGV98VCR',
#    'name': '2A e 3A volta',
#    'type': 'open',
#    'badgeId': 16000000,
#    'clanScore': 53556,
#    'clanWarTrophies': 400,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 1600,
#    'donationsPerWeek': 1019,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 22},
#   {'tag': '#2PQ08RP0',
#    'name': '2LT',
#    'type': 'open',
#    'badgeId': 16000078,
#    'clanScore': 63346,
#    'clanWarTrophies': 1720,
#    'location': {'id': 57000087,
#     'name': 'France',
#     'isCountry': True,
#     'countryCode': 'FR'},
#    'requiredTrophies': 8500,
#    'donationsPerWeek': 1240,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#GGP80VJL',
#    'name': '40шк',
#    'type': 'open',
#    'badgeId': 16000120,
#    'clanScore': 35720,
#    'clanWarTrophies': 130,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 946,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 22},
#   {'tag': '#RPLVJRRR',
#    'name': '42 пацаны',
#    'type': 'open',
#    'badgeId': 16000029,
#    'clanScore': 45784,
#    'clanWarTrophies': 160,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 720,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 23},
#   {'tag': '#QJGVVCGG',
#    'name': '4AK',
#    'type': 'open',
#    'badgeId': 16000139,
#    'clanScore': 52383,
#    'clanWarTrophies': 120,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 807,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 21},
#   {'tag': '#QCRRQVLC',
#    'name': '51번개',
#    'type': 'open',
#    'badgeId': 16000010,
#    'clanScore': 52771,
#    'clanWarTrophies': 60,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 1211,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 25},
#   {'tag': '#QCQ89GY0',
#    'name': '547',
#    'type': 'open',
#    'badgeId': 16000139,
#    'clanScore': 36770,
#    'clanWarTrophies': 290,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 1318,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 24},
#   {'tag': '#R8QQ8G2G',
#    'name': '6반게이',
#    'type': 'open',
#    'badgeId': 16000126,
#    'clanScore': 55685,
#    'clanWarTrophies': 30,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 300,
#    'donationsPerWeek': 922,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 21},
#   {'tag': '#GY808CPC',
#    'name': '7반 고추밭',
#    'type': 'inviteOnly',
#    'badgeId': 16000126,
#    'clanScore': 57987,
#    'clanWarTrophies': 200,
#    'location': {'id': 57000174,
#     'name': 'North Korea',
#     'isCountry': True,
#     'countryCode': 'KP'},
#    'requiredTrophies': 300,
#    'donationsPerWeek': 612,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 26},
#   {'tag': '#GQ8UQGVP',
#    'name': '9876',
#    'type': 'closed',
#    'badgeId': 16000175,
#    'clanScore': 33284,
#    'clanWarTrophies': 480,
#    'location': {'id': 57000040,
#     'name': 'British Virgin Islands',
#     'isCountry': True,
#     'countryCode': 'VG'},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 550,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 21},
#   {'tag': '#G8RRU9PQ',
#    'name': '999999',
#    'type': 'open',
#    'badgeId': 16000128,
#    'clanScore': 47423,
#    'clanWarTrophies': 194,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 494,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 22},
#   {'tag': '#GQJUCJYR',
#    'name': '9А ЭЛИТКИ',
#    'type': 'inviteOnly',
#    'badgeId': 16000072,
#    'clanScore': 40247,
#    'clanWarTrophies': 160,
#    'location': {'id': 57000177,
#     'name': 'Oman',
#     'isCountry': True,
#     'countryCode': 'OM'},
#    'requiredTrophies': 1000,
#    'donationsPerWeek': 1253,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 21},
#   {'tag': '#QCQURGLL',
#    'name': '9В крутой',
#    'type': 'open',
#    'badgeId': 16000072,
#    'clanScore': 32889,
#    'clanWarTrophies': 472,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 1000,
#    'donationsPerWeek': 1260,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 21},
#   {'tag': '#GG2GYJRY',
#    'name': '9д кайф',
#    'type': 'open',
#    'badgeId': 16000004,
#    'clanScore': 36712,
#    'clanWarTrophies': 200,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 827,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#G8CVR0UR',
#    'name': '@#VIKINGOS#@',
#    'type': 'inviteOnly',
#    'badgeId': 16000164,
#    'clanScore': 45677,
#    'clanWarTrophies': 1000,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 586,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 21},
#   {'tag': '#QUQPLJ9V',
#    'name': '[Sp]SuperPlayer',
#    'type': 'open',
#    'badgeId': 16000131,
#    'clanScore': 30452,
#    'clanWarTrophies': 190,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 400,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#GP98QPPV',
#    'name': '_Wisanggeni_',
#    'type': 'inviteOnly',
#    'badgeId': 16000173,
#    'clanScore': 31943,
#    'clanWarTrophies': 190,
#    'location': {'id': 57000114,
#     'name': 'Indonesia',
#     'isCountry': True,
#     'countryCode': 'ID'},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 1201,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 22},
#   {'tag': '#G8C8RVQC',
#    'name': 'A&A',
#    'type': 'open',
#    'badgeId': 16000002,
#    'clanScore': 32439,
#    'clanWarTrophies': 765,
#    'location': {'id': 57000094,
#     'name': 'Germany',
#     'isCountry': True,
#     'countryCode': 'DE'},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 1063,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#QVG2LJYG',
#    'name': 'a-level gng',
#    'type': 'inviteOnly',
#    'badgeId': 16000121,
#    'clanScore': 57742,
#    'clanWarTrophies': 150,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 600,
#    'donationsPerWeek': 938,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 25},
#   {'tag': '#QU2L2GGQ',
#    'name': 'aböm',
#    'type': 'open',
#    'badgeId': 16000030,
#    'clanScore': 44755,
#    'clanWarTrophies': 180,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 651,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 26},
#   {'tag': '#QG92GV',
#    'name': 'ACE KILLER',
#    'type': 'open',
#    'badgeId': 16000108,
#    'clanScore': 60385,
#    'clanWarTrophies': 1545,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 4000,
#    'donationsPerWeek': 1190,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#P8R9JU29',
#    'name': 'ADVENTURE INDO',
#    'type': 'open',
#    'badgeId': 16000173,
#    'clanScore': 57318,
#    'clanWarTrophies': 2956,
#    'location': {'id': 57000114,
#     'name': 'Indonesia',
#     'isCountry': True,
#     'countryCode': 'ID'},
#    'requiredTrophies': 4000,
#    'donationsPerWeek': 1421,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#QYULCYV0',
#    'name': 'aehyang',
#    'type': 'inviteOnly',
#    'badgeId': 16000126,
#    'clanScore': 45229,
#    'clanWarTrophies': 658,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 1120,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 22},
#   {'tag': '#QCPU0RCQ',
#    'name': 'AgNO3',
#    'type': 'open',
#    'badgeId': 16000024,
#    'clanScore': 38244,
#    'clanWarTrophies': 10,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 786,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 22},
#   {'tag': '#QCJUQU89',
#    'name': 'aguante el defe',
#    'type': 'inviteOnly',
#    'badgeId': 16000016,
#    'clanScore': 41379,
#    'clanWarTrophies': 548,
#    'location': {'id': 57000017,
#     'name': 'Argentina',
#     'isCountry': True,
#     'countryCode': 'AR'},
#    'requiredTrophies': 600,
#    'donationsPerWeek': 686,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 23},
#   {'tag': '#QL2YQUCV',
#    'name': 'Albupan',
#    'type': 'open',
#    'badgeId': 16000159,
#    'clanScore': 41075,
#    'clanWarTrophies': 546,
#    'location': {'id': 57000218,
#     'name': 'Spain',
#     'isCountry': True,
#     'countryCode': 'ES'},
#    'requiredTrophies': 5000,
#    'donationsPerWeek': 534,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#QC0U2U90',
#    'name': 'allahu akbar',
#    'type': 'open',
#    'badgeId': 16000128,
#    'clanScore': 56992,
#    'clanWarTrophies': 500,
#    'location': {'id': 57000094,
#     'name': 'Germany',
#     'isCountry': True,
#     'countryCode': 'DE'},
#    'requiredTrophies': 4000,
#    'donationsPerWeek': 1058,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 27},
#   {'tag': '#G292PG8V',
#    'name': 'AllBotoNoBallz',
#    'type': 'open',
#    'badgeId': 16000131,
#    'clanScore': 59910,
#    'clanWarTrophies': 1650,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 300,
#    'donationsPerWeek': 1190,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 23},
#   {'tag': '#QU0LUYUR',
#    'name': 'Alp Ömer Bilgin',
#    'type': 'open',
#    'badgeId': 16000030,
#    'clanScore': 36707,
#    'clanWarTrophies': 50,
#    'location': {'id': 57000239,
#     'name': 'Turkey',
#     'isCountry': True,
#     'countryCode': 'TR'},
#    'requiredTrophies': 1000,
#    'donationsPerWeek': 398,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 23},
#   {'tag': '#RPGJQV0U',
#    'name': 'AlphaMMA',
#    'type': 'open',
#    'badgeId': 16000012,
#    'clanScore': 47103,
#    'clanWarTrophies': 293,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 744,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#RYRJV820',
#    'name': 'AMMA Royale',
#    'type': 'inviteOnly',
#    'badgeId': 16000077,
#    'clanScore': 53704,
#    'clanWarTrophies': 720,
#    'location': {'id': 57000113,
#     'name': 'India',
#     'isCountry': True,
#     'countryCode': 'IN'},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 796,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 21},
#   {'tag': '#QVLQ2Y80',
#    'name': 'andi ostfront',
#    'type': 'open',
#    'badgeId': 16000009,
#    'clanScore': 37752,
#    'clanWarTrophies': 210,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 525,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 21},
#   {'tag': '#GLQ8PYUR',
#    'name': 'angkasa jaya',
#    'type': 'open',
#    'badgeId': 16000010,
#    'clanScore': 62660,
#    'clanWarTrophies': 1095,
#    'location': {'id': 57000114,
#     'name': 'Indonesia',
#     'isCountry': True,
#     'countryCode': 'ID'},
#    'requiredTrophies': 5000,
#    'donationsPerWeek': 1840,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 28},
#   {'tag': '#9PYP0CGR',
#    'name': 'Angry Family',
#    'type': 'open',
#    'badgeId': 16000167,
#    'clanScore': 37557,
#    'clanWarTrophies': 877,
#    'location': {'id': 57000216,
#     'name': 'South Korea',
#     'isCountry': True,
#     'countryCode': 'KR'},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 624,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#GP8RR90Q',
#    'name': 'an¥c',
#    'type': 'open',
#    'badgeId': 16000072,
#    'clanScore': 40097,
#    'clanWarTrophies': 180,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 298,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#QJ0GP9LV',
#    'name': 'Apina Plantaasi',
#    'type': 'open',
#    'badgeId': 16000167,
#    'clanScore': 43780,
#    'clanWarTrophies': 230,
#    'location': {'id': 57000086,
#     'name': 'Finland',
#     'isCountry': True,
#     'countryCode': 'FI'},
#    'requiredTrophies': 5000,
#    'donationsPerWeek': 1723,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 22},
#   {'tag': '#8GGGC9L0',
#    'name': 'APOCALIPSiS',
#    'type': 'open',
#    'badgeId': 16000107,
#    'clanScore': 63920,
#    'clanWarTrophies': 1732,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 6500,
#    'donationsPerWeek': 484,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 24},
#   {'tag': '#QCLU0J8J',
#    'name': 'Arcadia',
#    'type': 'open',
#    'badgeId': 16000162,
#    'clanScore': 44329,
#    'clanWarTrophies': 100,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 614,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 22},
#   {'tag': '#G8U09QJC',
#    'name': 'ARGENTINA',
#    'type': 'open',
#    'badgeId': 16000162,
#    'clanScore': 47688,
#    'clanWarTrophies': 890,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 1000,
#    'donationsPerWeek': 1056,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 21},
#   {'tag': '#QP9P9VJY',
#    'name': 'ariy',
#    'type': 'open',
#    'badgeId': 16000170,
#    'clanScore': 51639,
#    'clanWarTrophies': 996,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 208,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 24},
#   {'tag': '#GP089UCQ',
#    'name': 'Armiata',
#    'type': 'open',
#    'badgeId': 16000120,
#    'clanScore': 32319,
#    'clanWarTrophies': 80,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 600,
#    'donationsPerWeek': 740,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#RY8C9CQP',
#    'name': 'arnas gejus',
#    'type': 'open',
#    'badgeId': 16000008,
#    'clanScore': 39448,
#    'clanWarTrophies': 0,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 1070,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#RQJQJPR9',
#    'name': 'Arriba los crac',
#    'type': 'inviteOnly',
#    'badgeId': 16000151,
#    'clanScore': 49003,
#    'clanWarTrophies': 90,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 600,
#    'donationsPerWeek': 429,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 23},
#   {'tag': '#QCV2PPQC',
#    'name': 'ARTEM WOLVES',
#    'type': 'open',
#    'badgeId': 16000047,
#    'clanScore': 40279,
#    'clanWarTrophies': 60,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 993,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 23},
#   {'tag': '#QJ28VPCP',
#    'name': 'Astana',
#    'type': 'open',
#    'badgeId': 16000055,
#    'clanScore': 51282,
#    'clanWarTrophies': 70,
#    'location': {'id': 57000125,
#     'name': 'Kazakhstan',
#     'isCountry': True,
#     'countryCode': 'KZ'},
#    'requiredTrophies': 4000,
#    'donationsPerWeek': 120,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 21},
#   {'tag': '#RYPYGJG',
#    'name': 'Aura.Aurora',
#    'type': 'open',
#    'badgeId': 16000020,
#    'clanScore': 68605,
#    'clanWarTrophies': 1499,
#    'location': {'id': 57000144,
#     'name': 'Malaysia',
#     'isCountry': True,
#     'countryCode': 'MY'},
#    'requiredTrophies': 7000,
#    'donationsPerWeek': 896,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 24},
#   {'tag': '#R02PRV8C',
#    'name': 'AVENGERS',
#    'type': 'inviteOnly',
#    'badgeId': 16000077,
#    'clanScore': 48217,
#    'clanWarTrophies': 1680,
#    'location': {'id': 57000034,
#     'name': 'Bolivia',
#     'isCountry': True,
#     'countryCode': 'BO'},
#    'requiredTrophies': 600,
#    'donationsPerWeek': 1624,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 24},
#   {'tag': '#GPL80GJV',
#    'name': 'aye',
#    'type': 'open',
#    'badgeId': 16000024,
#    'clanScore': 51608,
#    'clanWarTrophies': 110,
#    'location': {'id': 57000193,
#     'name': 'Russia',
#     'isCountry': True,
#     'countryCode': 'RU'},
#    'requiredTrophies': 5000,
#    'donationsPerWeek': 653,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#R8CGP8CQ',
#    'name': 'AZTLAN',
#    'type': 'inviteOnly',
#    'badgeId': 16000081,
#    'clanScore': 38691,
#    'clanWarTrophies': 124,
#    'location': {'id': 57000153,
#     'name': 'Mexico',
#     'isCountry': True,
#     'countryCode': 'MX'},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 2800,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#QQGQV2Y0',
#    'name': 'babaprosigmalar',
#    'type': 'open',
#    'badgeId': 16000041,
#    'clanScore': 45801,
#    'clanWarTrophies': 1058,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 655,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#QUJJPU8P',
#    'name': 'babyjonny',
#    'type': 'open',
#    'badgeId': 16000120,
#    'clanScore': 41620,
#    'clanWarTrophies': 90,
#    'location': {'id': 57000193,
#     'name': 'Russia',
#     'isCountry': True,
#     'countryCode': 'RU'},
#    'requiredTrophies': 2000,
#    'donationsPerWeek': 815,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#G20C9LRQ',
#    'name': 'BAMBOO Play',
#    'type': 'open',
#    'badgeId': 16000139,
#    'clanScore': 46443,
#    'clanWarTrophies': 368,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 4300,
#    'donationsPerWeek': 1136,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#QG2Y0VQR',
#    'name': 'Banda Plebsów',
#    'type': 'inviteOnly',
#    'badgeId': 16000173,
#    'clanScore': 30952,
#    'clanWarTrophies': 160,
#    'location': {'id': 57000187,
#     'name': 'Poland',
#     'isCountry': True,
#     'countryCode': 'PL'},
#    'requiredTrophies': 3000,
#    'donationsPerWeek': 1035,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#QV0YUU9Y',
#    'name': 'Barbariani',
#    'type': 'open',
#    'badgeId': 16000030,
#    'clanScore': 39852,
#    'clanWarTrophies': 50,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 423,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 21},
#   {'tag': '#GQJLUVUR',
#    'name': 'bardelax du 22',
#    'type': 'open',
#    'badgeId': 16000122,
#    'clanScore': 56637,
#    'clanWarTrophies': 530,
#    'location': {'id': 57000000, 'name': 'Europe', 'isCountry': False},
#    'requiredTrophies': 3000,
#    'donationsPerWeek': 1226,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 29},
#   {'tag': '#GPPVU08V',
#    'name': 'BDR125',
#    'type': 'open',
#    'badgeId': 16000033,
#    'clanScore': 58421,
#    'clanWarTrophies': 160,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 2000,
#    'donationsPerWeek': 1295,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 21},
#   {'tag': '#QCU8LPVV',
#    'name': 'BeautifulStasis',
#    'type': 'open',
#    'badgeId': 16000009,
#    'clanScore': 32570,
#    'clanWarTrophies': 160,
#    'location': {'id': 57000180,
#     'name': 'Palestine',
#     'isCountry': True,
#     'countryCode': 'PS'},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 980,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#R0JYY00U',
#    'name': 'behind you',
#    'type': 'open',
#    'badgeId': 16000007,
#    'clanScore': 40159,
#    'clanWarTrophies': 470,
#    'location': {'id': 57000138,
#     'name': 'Lithuania',
#     'isCountry': True,
#     'countryCode': 'LT'},
#    'requiredTrophies': 600,
#    'donationsPerWeek': 1312,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 21},
#   {'tag': '#QPPRPGRY',
#    'name': 'bejica love',
#    'type': 'open',
#    'badgeId': 16000107,
#    'clanScore': 55204,
#    'clanWarTrophies': 427,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 3600,
#    'donationsPerWeek': 1390,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 21},
#   {'tag': '#QC02LQ29',
#    'name': 'best of iran',
#    'type': 'open',
#    'badgeId': 16000165,
#    'clanScore': 58083,
#    'clanWarTrophies': 500,
#    'location': {'id': 57000115,
#     'name': 'Iran',
#     'isCountry': True,
#     'countryCode': 'IR'},
#    'requiredTrophies': 6000,
#    'donationsPerWeek': 1786,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 22},
#   {'tag': '#GPQVV8YQ',
#    'name': 'BG MLADOCI',
#    'type': 'open',
#    'badgeId': 16000023,
#    'clanScore': 52131,
#    'clanWarTrophies': 110,
#    'location': {'id': 57000042,
#     'name': 'Bulgaria',
#     'isCountry': True,
#     'countryCode': 'BG'},
#    'requiredTrophies': 4300,
#    'donationsPerWeek': 1077,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#QVG0C2UP',
#    'name': 'Big cool bois',
#    'type': 'open',
#    'badgeId': 16000125,
#    'clanScore': 47991,
#    'clanWarTrophies': 150,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 1184,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 23},
#   {'tag': '#QCCG8G2Q',
#    'name': 'big rig',
#    'type': 'open',
#    'badgeId': 16000050,
#    'clanScore': 29146,
#    'clanWarTrophies': 30,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 2000,
#    'donationsPerWeek': 1133,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#R0VRPJP0',
#    'name': 'bin',
#    'type': 'open',
#    'badgeId': 16000154,
#    'clanScore': 53832,
#    'clanWarTrophies': 263,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 848,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 25},
#   {'tag': '#LPPYPRRL',
#    'name': 'Black Panter',
#    'type': 'open',
#    'badgeId': 16000002,
#    'clanScore': 49440,
#    'clanWarTrophies': 980,
#    'location': {'id': 57000144,
#     'name': 'Malaysia',
#     'isCountry': True,
#     'countryCode': 'MY'},
#    'requiredTrophies': 5500,
#    'donationsPerWeek': 1150,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 22},
#   {'tag': '#P8YJ0Q9Y',
#    'name': 'BLOOdY bLasteRS',
#    'type': 'open',
#    'badgeId': 16000024,
#    'clanScore': 42536,
#    'clanWarTrophies': 1498,
#    'location': {'id': 57000113,
#     'name': 'India',
#     'isCountry': True,
#     'countryCode': 'IN'},
#    'requiredTrophies': 2000,
#    'donationsPerWeek': 1058,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#QUVQ2V8P',
#    'name': 'BobbyHaters',
#    'type': 'open',
#    'badgeId': 16000140,
#    'clanScore': 57261,
#    'clanWarTrophies': 1677,
#    'location': {'id': 57000000, 'name': 'Europe', 'isCountry': False},
#    'requiredTrophies': 7500,
#    'donationsPerWeek': 765,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 24},
#   {'tag': '#RPQC9GJG',
#    'name': 'Bobobobo',
#    'type': 'open',
#    'badgeId': 16000012,
#    'clanScore': 53031,
#    'clanWarTrophies': 480,
#    'location': {'id': 57000000, 'name': 'Europe', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 1196,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 24},
#   {'tag': '#QULVL2G9',
#    'name': 'Boduk',
#    'type': 'open',
#    'badgeId': 16000175,
#    'clanScore': 28757,
#    'clanWarTrophies': 150,
#    'location': {'id': 57000246,
#     'name': 'Ukraine',
#     'isCountry': True,
#     'countryCode': 'UA'},
#    'requiredTrophies': 2000,
#    'donationsPerWeek': 1090,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 22},
#   {'tag': '#YJGQUCJ0',
#    'name': 'Bokey',
#    'type': 'open',
#    'badgeId': 16000029,
#    'clanScore': 63142,
#    'clanWarTrophies': 2569,
#    'location': {'id': 57000165,
#     'name': 'Nepal',
#     'isCountry': True,
#     'countryCode': 'NP'},
#    'requiredTrophies': 2000,
#    'donationsPerWeek': 2002,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 23},
#   {'tag': '#RLGQVRRL',
#    'name': 'Bone Crown',
#    'type': 'open',
#    'badgeId': 16000024,
#    'clanScore': 58503,
#    'clanWarTrophies': 805,
#    'location': {'id': 57000001, 'name': 'North America', 'isCountry': False},
#    'requiredTrophies': 3000,
#    'donationsPerWeek': 682,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#RY98R8UP',
#    'name': 'borko ludiq',
#    'type': 'open',
#    'badgeId': 16000124,
#    'clanScore': 52321,
#    'clanWarTrophies': 0,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 611,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 21},
#   {'tag': '#G9JCL829',
#    'name': 'boruta nwd',
#    'type': 'open',
#    'badgeId': 16000035,
#    'clanScore': 55848,
#    'clanWarTrophies': 74,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 1312,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 30},
#   {'tag': '#GP9CVC0Q',
#    'name': 'Boykottierer',
#    'type': 'open',
#    'badgeId': 16000001,
#    'clanScore': 30568,
#    'clanWarTrophies': 70,
#    'location': {'id': 57000094,
#     'name': 'Germany',
#     'isCountry': True,
#     'countryCode': 'DE'},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 582,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 21},
#   {'tag': '#GQCV2VPV',
#    'name': 'BrilliantMoment',
#    'type': 'inviteOnly',
#    'badgeId': 16000167,
#    'clanScore': 57900,
#    'clanWarTrophies': 142,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 300,
#    'donationsPerWeek': 2136,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 27},
#   {'tag': '#QJUQP8U0',
#    'name': 'brood',
#    'type': 'open',
#    'badgeId': 16000000,
#    'clanScore': 58701,
#    'clanWarTrophies': 130,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 2000,
#    'donationsPerWeek': 832,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 29},
#   {'tag': '#QUP8YJCC',
#    'name': 'bruzzvengers',
#    'type': 'open',
#    'badgeId': 16000177,
#    'clanScore': 56356,
#    'clanWarTrophies': 0,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 846,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 22},
#   {'tag': '#QRVYJQ29',
#    'name': 'BTS MS',
#    'type': 'inviteOnly',
#    'badgeId': 16000078,
#    'clanScore': 55252,
#    'clanWarTrophies': 349,
#    'location': {'id': 57000087,
#     'name': 'France',
#     'isCountry': True,
#     'countryCode': 'FR'},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 782,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 24},
#   {'tag': '#QQ0LJ900',
#    'name': 'C.A.Paraliticos',
#    'type': 'open',
#    'badgeId': 16000021,
#    'clanScore': 52483,
#    'clanWarTrophies': 1632,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 674,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#2UVJPJ88',
#    'name': 'CarAnchoa',
#    'type': 'open',
#    'badgeId': 16000172,
#    'clanScore': 49470,
#    'clanWarTrophies': 1508,
#    'location': {'id': 57000218,
#     'name': 'Spain',
#     'isCountry': True,
#     'countryCode': 'ES'},
#    'requiredTrophies': 4000,
#    'donationsPerWeek': 1045,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#Y8R2LUVV',
#    'name': 'Carlitox Clan',
#    'type': 'closed',
#    'badgeId': 16000015,
#    'clanScore': 43201,
#    'clanWarTrophies': 3175,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 950,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#99QU0G',
#    'name': 'CATALUNYA BB',
#    'type': 'inviteOnly',
#    'badgeId': 16000061,
#    'clanScore': 62803,
#    'clanWarTrophies': 1670,
#    'location': {'id': 57000159,
#     'name': 'Montserrat',
#     'isCountry': True,
#     'countryCode': 'MS'},
#    'requiredTrophies': 5000,
#    'donationsPerWeek': 484,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 22},
#   {'tag': '#QCGPQPGY',
#    'name': 'Cherry Blossom',
#    'type': 'open',
#    'badgeId': 16000128,
#    'clanScore': 42779,
#    'clanWarTrophies': 0,
#    'location': {'id': 57000216,
#     'name': 'South Korea',
#     'isCountry': True,
#     'countryCode': 'KR'},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 736,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 21},
#   {'tag': '#GPPCPP02',
#    'name': 'Child service',
#    'type': 'open',
#    'badgeId': 16000077,
#    'clanScore': 38980,
#    'clanWarTrophies': 50,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 306,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#RQC0UQYU',
#    'name': 'chochoły',
#    'type': 'open',
#    'badgeId': 16000173,
#    'clanScore': 45984,
#    'clanWarTrophies': 100,
#    'location': {'id': 57000000, 'name': 'Europe', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 698,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 21},
#   {'tag': '#QVCJYVRV',
#    'name': 'ChutPaglu',
#    'type': 'open',
#    'badgeId': 16000002,
#    'clanScore': 39564,
#    'clanWarTrophies': 140,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 212,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#QC298U80',
#    'name': 'CipollaRolls',
#    'type': 'open',
#    'badgeId': 16000054,
#    'clanScore': 39911,
#    'clanWarTrophies': 180,
#    'location': {'id': 57000120,
#     'name': 'Italy',
#     'isCountry': True,
#     'countryCode': 'IT'},
#    'requiredTrophies': 2000,
#    'donationsPerWeek': 930,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#QJ9V8G2G',
#    'name': 'Clan #QJ9V8G2G',
#    'type': 'open',
#    'badgeId': 16000144,
#    'clanScore': 46452,
#    'clanWarTrophies': 509,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 1584,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 24},
#   {'tag': '#RLJYVQQG',
#    'name': 'Clan #RLJYVQQG',
#    'type': 'open',
#    'badgeId': 16000108,
#    'clanScore': 51774,
#    'clanWarTrophies': 680,
#    'location': {'id': 57000170,
#     'name': 'Niger',
#     'isCountry': True,
#     'countryCode': 'NE'},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 1355,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#Q9YRCV90',
#    'name': 'clan universo 7',
#    'type': 'open',
#    'badgeId': 16000124,
#    'clanScore': 47071,
#    'clanWarTrophies': 1889,
#    'location': {'id': 57000169,
#     'name': 'Nicaragua',
#     'isCountry': True,
#     'countryCode': 'NI'},
#    'requiredTrophies': 1300,
#    'donationsPerWeek': 1156,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#RPLCG9UU',
#    'name': 'Clara',
#    'type': 'inviteOnly',
#    'badgeId': 16000171,
#    'clanScore': 71840,
#    'clanWarTrophies': 775,
#    'location': {'id': 57000216,
#     'name': 'South Korea',
#     'isCountry': True,
#     'countryCode': 'KR'},
#    'requiredTrophies': 7500,
#    'donationsPerWeek': 2086,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 26},
#   {'tag': '#P2099R',
#    'name': 'Clash HQ',
#    'type': 'open',
#    'badgeId': 16000007,
#    'clanScore': 53834,
#    'clanWarTrophies': 1568,
#    'location': {'id': 57000144,
#     'name': 'Malaysia',
#     'isCountry': True,
#     'countryCode': 'MY'},
#    'requiredTrophies': 3000,
#    'donationsPerWeek': 1196,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 21},
#   {'tag': '#QUQ9QVY8',
#    'name': 'clashlucks',
#    'type': 'open',
#    'badgeId': 16000124,
#    'clanScore': 41677,
#    'clanWarTrophies': 150,
#    'location': {'id': 57000038,
#     'name': 'Brazil',
#     'isCountry': True,
#     'countryCode': 'BR'},
#    'requiredTrophies': 2000,
#    'donationsPerWeek': 550,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 21},
#   {'tag': '#2Y0JCQRG',
#    'name': 'ClashRoyale Mex',
#    'type': 'inviteOnly',
#    'badgeId': 16000081,
#    'clanScore': 32421,
#    'clanWarTrophies': 2164,
#    'location': {'id': 57000153,
#     'name': 'Mexico',
#     'isCountry': True,
#     'countryCode': 'MX'},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 1120,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 21},
#   {'tag': '#QPP8YVQ8',
#    'name': 'clementi prime',
#    'type': 'inviteOnly',
#    'badgeId': 16000028,
#    'clanScore': 46460,
#    'clanWarTrophies': 1504,
#    'location': {'id': 57000000, 'name': 'Europe', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 532,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 21},
#   {'tag': '#JV0V8LQ',
#    'name': 'Coalizão Brasil',
#    'type': 'closed',
#    'badgeId': 16000044,
#    'clanScore': 62468,
#    'clanWarTrophies': 3485,
#    'location': {'id': 57000038,
#     'name': 'Brazil',
#     'isCountry': True,
#     'countryCode': 'BR'},
#    'requiredTrophies': 9000,
#    'donationsPerWeek': 638,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#QC0U928Y',
#    'name': 'cold palmer',
#    'type': 'open',
#    'badgeId': 16000168,
#    'clanScore': 54925,
#    'clanWarTrophies': 190,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 1000,
#    'donationsPerWeek': 586,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 24},
#   {'tag': '#QYL9RJUG',
#    'name': 'Comu FC',
#    'type': 'open',
#    'badgeId': 16000142,
#    'clanScore': 49134,
#    'clanWarTrophies': 544,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 969,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 23},
#   {'tag': '#RP9CUL8G',
#    'name': 'coolBoys',
#    'type': 'open',
#    'badgeId': 16000171,
#    'clanScore': 61453,
#    'clanWarTrophies': 599,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 5000,
#    'donationsPerWeek': 1216,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 27},
#   {'tag': '#RPL8VLLQ',
#    'name': 'couyal’ere',
#    'type': 'inviteOnly',
#    'badgeId': 16000078,
#    'clanScore': 47093,
#    'clanWarTrophies': 140,
#    'location': {'id': 57000087,
#     'name': 'France',
#     'isCountry': True,
#     'countryCode': 'FR'},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 329,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 22},
#   {'tag': '#QG02YR28',
#    'name': 'Cricket Camp',
#    'type': 'inviteOnly',
#    'badgeId': 16000171,
#    'clanScore': 52288,
#    'clanWarTrophies': 1459,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 338,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 22},
#   {'tag': '#QUJURRCU',
#    'name': 'CRST',
#    'type': 'inviteOnly',
#    'badgeId': 16000008,
#    'clanScore': 48393,
#    'clanWarTrophies': 0,
#    'location': {'id': 57000216,
#     'name': 'South Korea',
#     'isCountry': True,
#     'countryCode': 'KR'},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 1664,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#QC2GUPVY',
#    'name': 'Crâne D’oeuf',
#    'type': 'open',
#    'badgeId': 16000154,
#    'clanScore': 55711,
#    'clanWarTrophies': 421,
#    'location': {'id': 57000087,
#     'name': 'France',
#     'isCountry': True,
#     'countryCode': 'FR'},
#    'requiredTrophies': 3000,
#    'donationsPerWeek': 516,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 22},
#   {'tag': '#RQ98V9J0',
#    'name': 'CXminシ',
#    'type': 'open',
#    'badgeId': 16000118,
#    'clanScore': 57888,
#    'clanWarTrophies': 195,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 2000,
#    'donationsPerWeek': 1461,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 24},
#   {'tag': '#RPV880V9',
#    'name': 'DARK',
#    'type': 'open',
#    'badgeId': 16000072,
#    'clanScore': 26878,
#    'clanWarTrophies': 150,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
# ...
#    'clanChestMaxLevel': 0,
#    'members': 24},
#   {'tag': '#QYVLVYLR',
#    'name': '클랜 #QYVLVYLR',
#    'type': 'open',
#    'badgeId': 16000126,
#    'clanScore': 44402,
#    'clanWarTrophies': 219,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 618,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 23},
#   {'tag': '#R0JCCRGL',
#    'name': '클랜 #R0JCCRGL',
#    'type': 'open',
#    'badgeId': 16000167,
#    'clanScore': 44010,
#    'clanWarTrophies': 270,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 1236,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 23},
#   {'tag': '#RLG8JCG9',
#    'name': '클랜 #RLG8JCG9',
#    'type': 'open',
#    'badgeId': 16000026,
#    'clanScore': 51609,
#    'clanWarTrophies': 126,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 1296,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#RY2CJL28',
#    'name': '클랜 #RY2CJL28',
#    'type': 'open',
#    'badgeId': 16000139,
#    'clanScore': 47332,
#    'clanWarTrophies': 120,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 719,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 21},
#   {'tag': '#QCG90YVJ',
#    'name': '클랜 아님',
#    'type': 'inviteOnly',
#    'badgeId': 16000121,
#    'clanScore': 44947,
#    'clanWarTrophies': 120,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 1817,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#RQR2VUGY',
#    'name': '클랜토리스',
#    'type': 'open',
#    'badgeId': 16000126,
#    'clanScore': 53619,
#    'clanWarTrophies': 0,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 938,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 23},
#   {'tag': '#R8Y990R0',
#    'name': '클로하는사람',
#    'type': 'open',
#    'badgeId': 16000104,
#    'clanScore': 54746,
#    'clanWarTrophies': 100,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 1150,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 30},
#   {'tag': '#Q2C8YY80',
#    'name': '타노스와친구들',
#    'type': 'closed',
#    'badgeId': 16000016,
#    'clanScore': 60798,
#    'clanWarTrophies': 1057,
#    'location': {'id': 57000216,
#     'name': 'South Korea',
#     'isCountry': True,
#     'countryCode': 'KR'},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 2125,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 28},
#   {'tag': '#QUCP80LP',
#    'name': '태용이시지인',
#    'type': 'open',
#    'badgeId': 16000168,
#    'clanScore': 47866,
#    'clanWarTrophies': 1082,
#    'location': {'id': 57000106,
#     'name': 'Guyana',
#     'isCountry': True,
#     'countryCode': 'GY'},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 611,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#R8CJG09U',
#    'name': '토끼자거부기한테',
#    'type': 'open',
#    'badgeId': 16000128,
#    'clanScore': 45018,
#    'clanWarTrophies': 32,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 778,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#QCVYYUL0',
#    'name': '트랄라레로 트랄랄라',
#    'type': 'open',
#    'badgeId': 16000111,
#    'clanScore': 46974,
#    'clanWarTrophies': 0,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 1000,
#    'donationsPerWeek': 927,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 29},
#   {'tag': '#GPLJ9R9L',
#    'name': '판교레브',
#    'type': 'open',
#    'badgeId': 16000091,
#    'clanScore': 44939,
#    'clanWarTrophies': 50,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 620,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 21},
#   {'tag': '#GQLYR920',
#    'name': '평고무지성집단',
#    'type': 'open',
#    'badgeId': 16000126,
#    'clanScore': 52205,
#    'clanWarTrophies': 130,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 1098,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 24},
#   {'tag': '#QG2CVUR2',
#    'name': '하늘교육연합',
#    'type': 'open',
#    'badgeId': 16000107,
#    'clanScore': 54999,
#    'clanWarTrophies': 481,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 1280,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 22},
#   {'tag': '#LRLLQLJU',
#    'name': '하늬중 얼짱클랜',
#    'type': 'open',
#    'badgeId': 16000126,
#    'clanScore': 60694,
#    'clanWarTrophies': 855,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 1000,
#    'donationsPerWeek': 891,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 28},
#   {'tag': '#GQUPYLGP',
#    'name': '하람이의 팬클럽',
#    'type': 'open',
#    'badgeId': 16000126,
#    'clanScore': 50712,
#    'clanWarTrophies': 30,
#    'location': {'id': 57000216,
#     'name': 'South Korea',
#     'isCountry': True,
#     'countryCode': 'KR'},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 1200,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 22},
#   {'tag': '#QV2Q8RUY',
#    'name': '하루중최고',
#    'type': 'open',
#    'badgeId': 16000028,
#    'clanScore': 49416,
#    'clanWarTrophies': 50,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 588,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 28},
#   {'tag': '#R0GQJ2YR',
#    'name': '한남동인',
#    'type': 'inviteOnly',
#    'badgeId': 16000128,
#    'clanScore': 47426,
#    'clanWarTrophies': 129,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 754,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#GG8CJUL8',
#    'name': '한울맘',
#    'type': 'open',
#    'badgeId': 16000014,
#    'clanScore': 49318,
#    'clanWarTrophies': 70,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 1324,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 25},
#   {'tag': '#QCRVJY2U',
#    'name': '한천우의 제자백가들',
#    'type': 'open',
#    'badgeId': 16000019,
#    'clanScore': 38789,
#    'clanWarTrophies': 10,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 420,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#RPUJ28YL',
#    'name': '해바라기해적단',
#    'type': 'open',
#    'badgeId': 16000133,
#    'clanScore': 51581,
#    'clanWarTrophies': 10,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 600,
#    'donationsPerWeek': 794,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 24},
#   {'tag': '#GGPQQG22',
#    'name': '해병군대',
#    'type': 'open',
#    'badgeId': 16000001,
#    'clanScore': 55211,
#    'clanWarTrophies': 30,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 1625,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 29},
#   {'tag': '#GP089CQP',
#    'name': '핸드폰제출',
#    'type': 'inviteOnly',
#    'badgeId': 16000176,
#    'clanScore': 51987,
#    'clanWarTrophies': 50,
#    'location': {'id': 57000216,
#     'name': 'South Korea',
#     'isCountry': True,
#     'countryCode': 'KR'},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 2427,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#GQLUPYUY',
#    'name': '햇빛고아원',
#    'type': 'open',
#    'badgeId': 16000127,
#    'clanScore': 41231,
#    'clanWarTrophies': 150,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 1645,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#R8L00JYL',
#    'name': '향호소년단',
#    'type': 'open',
#    'badgeId': 16000054,
#    'clanScore': 55437,
#    'clanWarTrophies': 50,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 1528,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 22},
#   {'tag': '#R2L2YGQU',
#    'name': '허무',
#    'type': 'open',
#    'badgeId': 16000129,
#    'clanScore': 55022,
#    'clanWarTrophies': 119,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 1234,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 21},
#   {'tag': '#QURVC8GQ',
#    'name': '헌s@e@x',
#    'type': 'open',
#    'badgeId': 16000126,
#    'clanScore': 46022,
#    'clanWarTrophies': 286,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 849,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 23},
#   {'tag': '#QV2GVQP9',
#    'name': '혁신이혁신을일으키다',
#    'type': 'open',
#    'badgeId': 16000140,
#    'clanScore': 58174,
#    'clanWarTrophies': 0,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 1261,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 23},
#   {'tag': '#R8J829YG',
#    'name': '현 빈 조',
#    'type': 'inviteOnly',
#    'badgeId': 16000126,
#    'clanScore': 53877,
#    'clanWarTrophies': 250,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 2054,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 24},
#   {'tag': '#RPJ0ULV9',
#    'name': '현대공고',
#    'type': 'open',
#    'badgeId': 16000054,
#    'clanScore': 51314,
#    'clanWarTrophies': 251,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 1246,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 24},
#   {'tag': '#G08J2R2J',
#    'name': '현민이 응빵이',
#    'type': 'open',
#    'badgeId': 16000130,
#    'clanScore': 51547,
#    'clanWarTrophies': 0,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 1580,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 22},
#   {'tag': '#GLPYP292',
#    'name': '현수 돼지',
#    'type': 'open',
#    'badgeId': 16000128,
#    'clanScore': 50129,
#    'clanWarTrophies': 104,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 799,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 28},
#   {'tag': '#R8UCRYV9',
#    'name': '현주띠',
#    'type': 'open',
#    'badgeId': 16000054,
#    'clanScore': 49756,
#    'clanWarTrophies': 10,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 965,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 27},
#   {'tag': '#QCCP2G2Y',
#    'name': '현준이 엄마',
#    'type': 'open',
#    'badgeId': 16000126,
#    'clanScore': 43530,
#    'clanWarTrophies': 185,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 743,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 25},
#   {'tag': '#RQJRQYVV',
#    'name': '형태클',
#    'type': 'open',
#    'badgeId': 16000127,
#    'clanScore': 42441,
#    'clanWarTrophies': 42,
#    'location': {'id': 57000216,
#     'name': 'South Korea',
#     'isCountry': True,
#     'countryCode': 'KR'},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 672,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#Q2GUCGRV',
#    'name': '혜지와수미의 반찬가게',
#    'type': 'open',
#    'badgeId': 16000178,
#    'clanScore': 57594,
#    'clanWarTrophies': 262,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 1456,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 29},
#   {'tag': '#QCQYLLGL',
#    'name': '홍과쫄병',
#    'type': 'inviteOnly',
#    'badgeId': 16000024,
#    'clanScore': 53298,
#    'clanWarTrophies': 56,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 1300,
#    'donationsPerWeek': 568,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 21},
#   {'tag': '#Q2JRVJ09',
#    'name': '홍삼바보',
#    'type': 'open',
#    'badgeId': 16000126,
#    'clanScore': 57827,
#    'clanWarTrophies': 882,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 2000,
#    'donationsPerWeek': 1298,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 30},
#   {'tag': '#GGRLRVGQ',
#    'name': '홍토리기모찌',
#    'type': 'inviteOnly',
#    'badgeId': 16000016,
#    'clanScore': 51396,
#    'clanWarTrophies': 0,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 2321,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 29},
#   {'tag': '#GP09G092',
#    'name': '화천옥타곤',
#    'type': 'open',
#    'badgeId': 16000020,
#    'clanScore': 62108,
#    'clanWarTrophies': 80,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 1224,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 28},
#   {'tag': '#QYRC2JQL',
#    'name': '효명',
#    'type': 'inviteOnly',
#    'badgeId': 16000054,
#    'clanScore': 55616,
#    'clanWarTrophies': 690,
#    'location': {'id': 57000216,
#     'name': 'South Korea',
#     'isCountry': True,
#     'countryCode': 'KR'},
#    'requiredTrophies': 5000,
#    'donationsPerWeek': 1950,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 21},
#   {'tag': '#G888Y09C',
#    'name': '후아유',
#    'type': 'open',
#    'badgeId': 16000054,
#    'clanScore': 42986,
#    'clanWarTrophies': 1403,
#    'location': {'id': 57000216,
#     'name': 'South Korea',
#     'isCountry': True,
#     'countryCode': 'KR'},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 1503,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 21},
#   {'tag': '#RQP80LV2',
#    'name': '훠이취',
#    'type': 'open',
#    'badgeId': 16000029,
#    'clanScore': 51458,
#    'clanWarTrophies': 70,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 1420,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 21},
#   {'tag': '#R8LV2GYL',
#    'name': '희찬fc',
#    'type': 'open',
#    'badgeId': 16000054,
#    'clanScore': 47538,
#    'clanWarTrophies': 15,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 983,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 24},
#   {'tag': '#8YQQJCVV',
#    'name': '히어로',
#    'type': 'open',
#    'badgeId': 16000009,
#    'clanScore': 56745,
#    'clanWarTrophies': 1422,
#    'location': {'id': 57000216,
#     'name': 'South Korea',
#     'isCountry': True,
#     'countryCode': 'KR'},
#    'requiredTrophies': 3300,
#    'donationsPerWeek': 1408,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#GLQ2VG08',
#    'name': 'ＶＩＫＩＮＧＳ',
#    'type': 'open',
#    'badgeId': 16000032,
#    'clanScore': 47286,
#    'clanWarTrophies': 1431,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 1109,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 26}],
#  'paging': {'cursors': {}}}

# %%
my_id = "ULCYC0UU"
battles = get_player_battles(my_id, key)
battles.head(3)
# Out:
#              battleTime    battleType          battleMode     arena  \
# 0  20250508T032734.000Z  pathOfLegend  Ranked1v1_NewArena  54000114
# 1  20250508T030738.000Z  pathOfLegend  Ranked1v1_NewArena  54000114
# 2  20250508T030326.000Z  pathOfLegend  Ranked1v1_NewArena  54000114
#
#         winner      loser  winner_card_1_id  winner_card_1_level  \
# 0   #Q0UVVYLUC  #ULCYC0UU          26000047                   11
# 1  #2002U9P0LC  #ULCYC0UU          26000024                   11
# 2   #P8PRV2UGC  #ULCYC0UU          26000036                    9
#
#    winner_card_2_id  winner_card_2_level  ...  loser_card_5_id  \
# 0          26000064                   11  ...         26000021
# 1          26000064                   11  ...         26000021
# 2          28000008                   11  ...         26000021
#
#    loser_card_5_level  loser_card_6_id  loser_card_6_level  loser_card_7_id  \
# 0                   9         26000041                  11         27000006
# 1                   9         26000041                  11         27000006
# 2                   9         26000041                  11         27000006
#
#    loser_card_7_level  loser_card_8_id  loser_card_8_level  \
# 0                  11         26000052                   9
# 1                  11         26000052                   9
# 2                  11         26000052                   9
#
#    loser_tower_card_id  loser_tower_card_level
# 0            159000000                      11
# 1            159000000                      11
# 2            159000000                      11
#
# [3 rows x 42 columns]

# %% [markdown]
# ## Downloading Entire Dataset

# %%
clanstest = get_clans_file(limit=100, minmembers=48, maxmembers=48, minscore=1000, key=key, max_clans=3000, output_file="clans_list_48.txt")
# Out:
# Retrieved 100 total clans so far...
# Retrieved 200 total clans so far...
# Retrieved 300 total clans so far...
# Retrieved 400 total clans so far...
# Retrieved 500 total clans so far...
# Retrieved 600 total clans so far...
# Retrieved 700 total clans so far...
# Retrieved 800 total clans so far...
# Retrieved 900 total clans so far...
# Reached the last page.
# Saved 960 clans to clans_list_48.txt

# %%
import time
slice_num = 9

# %%
for i in range(10):
    print(f"Retrieving clans {i*100} to {i*100 + 100}")
    clans = read_clans_range(start=i*100, end=i*100+100, file_name="clans_list_48.txt")
    df = get_full(file_name = f'48_clash_battles_{i*100}_{i*100 + 100}', num_clans=100, key=key, clans_list=clans, max_workers = 8)
    time.sleep(5)
# Out:
# Retrieving clans 0 to 100
# Retrieved 100 clans
# Retrieved 4800 players
# Saved final df to 48_clash_battles_0_100.csv.csv
# Done!
# Retrieving clans 100 to 200
# Retrieved 100 clans
# Retrieved 4800 players
# Saved final df to 48_clash_battles_100_200.csv.csv
# Done!
# Retrieving clans 200 to 300
# Retrieved 100 clans
# Retrieved 4801 players
# Saved final df to 48_clash_battles_200_300.csv.csv
# Done!
# Retrieving clans 300 to 400
# Retrieved 100 clans
# Retrieved 4800 players
# Saved final df to 48_clash_battles_300_400.csv.csv
# Done!
# Retrieving clans 400 to 500
# Retrieved 100 clans
# Retrieved 4803 players
# Saved final df to 48_clash_battles_400_500.csv.csv
# Done!
# Retrieving clans 500 to 600
# Retrieved 100 clans
# Retrieved 4801 players
# Saved final df to 48_clash_battles_500_600.csv.csv
# Done!
# Retrieving clans 600 to 700
# Retrieved 100 clans
# Retrieved 4802 players
# Saved final df to 48_clash_battles_600_700.csv.csv
# Done!
# Retrieving clans 700 to 800
# Retrieved 100 clans
# Retrieved 4800 players
# Saved final df to 48_clash_battles_700_800.csv.csv
# Done!
# Retrieving clans 800 to 900
# Retrieved 100 clans
# Retrieved 4801 players
# Saved final df to 48_clash_battles_800_900.csv.csv
# Done!
# Retrieving clans 900 to 1000
# Retrieved 60 clans
# Retrieved 2879 players
# Saved final df to 48_clash_battles_900_1000.csv.csv
# Done!

# %%
def check_clans_overlap(file1, file2):
    with open(file1, 'r') as f1, open(file2, 'r') as f2:
        clans1 = set(f1.read().splitlines())
        clans2 = set(f2.read().splitlines())
        overlap = clans1.intersection(clans2)
        return overlap

overlap = check_clans_overlap('clans_list_49.txt', 'clans_list_48.txt')
if overlap:
    print("There are clans that appear in both files:")
    print(overlap)
else:
    print("No clans appear in both files.")
# Out:
# No clans appear in both files.

# %% [markdown]
# ## Getting Card Dictionary for later

# %%
import json

fs = 'https://api.clashroyale.com/v1/cards'
y = call_api(fs, key).json()

card_mappings = {card['id']:card['name'] for card in y['items']}
tower_mappings = {card['id']:card['name'] for card in y['supportItems']}
card_mappings.update(tower_mappings)

json_data = json.dumps(card_mappings)

file_path = "./dicts/card_mappings.json"

with open(file_path, "w") as file:
    file.write(json_data)

# %%
file_path = "./dicts/card_info.json"

with open(file_path, "w") as file:
    json.dump(y, file)
