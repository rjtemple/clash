# %%
key = "eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzUxMiIsImtpZCI6IjI4YTMxOGY3LTAwMDAtYTFlYi03ZmExLTJjNzQzM2M2Y2NhNSJ9..-KSOtvMbnB17vu4qve2uy-3HnUBoZOEn17sxaUmVBoH3tA0I5ze5Pds_eZW9YZGMl5pSFAxhImCFGU-aj5q9GQ"

# %%
import requests
import pandas as pd
import json
from concurrent.futures import ThreadPoolExecutor, as_completed
import time
import requests
from itertools import islice

def read_clans_range(file_name="clans_list.txt", start=0, end=100):
    with open(file_name, "r") as f:
        # Use islice for efficient range reading
        clans = list(islice(f, start, end))
    # Strip whitespace and return as a list of strings
    return [clan.strip() for clan in clans]


def get_clans_file(limit=100, minmembers=50, maxmembers=50, minscore=1000, key="", max_clans=3000, output_file="clans_list.txt"):
    all_clans = []
    after = None
    
    while len(all_clans) < max_clans:
        # Build the base URL
        url = f"https://api.clashroyale.com/v1/clans?minMembers={minmembers}&maxMembers={maxmembers}&minScore={minscore}&limit={limit}"
        
        # Add the 'after' marker if present
        if after:
            url += f"&after={after}"
        
        # Make the API call
        headers = {"Authorization": f"Bearer {key}"}
        response = requests.get(url, headers=headers)
        
        if response.status_code == 200:
            data = response.json()
            clans = data.get("items", [])
            paging = data.get("paging", {})
            
            # Add the clans to the master list
            all_clans.extend(clan["tag"] for clan in clans)
            
            # Get the next 'after' marker
            after = paging.get("cursors", {}).get("after")
            
            # Stop if there are no more pages
            if not after:
                print("Reached the last page.")
                break
            
            print(f"Retrieved {len(all_clans)} total clans so far...")
        
        else:
            print(f"Error retrieving clans: {response.status_code} - {response.text}")
            break
    
    # Save the clans to a file
    with open(output_file, "w") as f:
        for clan in all_clans[:max_clans]:
            f.write(clan + "\n")
    
    print(f"Saved {len(all_clans[:max_clans])} clans to {output_file}")

def call_api(url, key, verbose = 0):
    headers = {
        "Authorization": f"Bearer {key}"
    }
    response = requests.get(url, headers=headers)
    if response.status_code == 200 and verbose > 0:
        print("Success!")
    elif verbose > 0:
        print(f"Error: {response.status_code}")
    return response

def battles_to_dataframe(battles, acceptable_types = ["PvP", "pathOfLegend"]):
    rows = []
    for battle in battles:
        if battle['type'] in acceptable_types:
            player_won = battle["team"][0]["crowns"] > battle["opponent"][0]["crowns"]
            winlose = ["team", "opponent"] if player_won else ["opponent", "team"]
            row = {
                "battleTime": battle["battleTime"],
                "battleType": battle["type"],
                "battleMode": battle["gameMode"]["name"],
                "arena": battle["arena"]["id"],
                "winner": battle[winlose[0]][0]["tag"],
                "loser": battle[winlose[1]][0]["tag"],
            }
            labels = ['winner', 'loser']
            for k in range(2):
                for i, player in enumerate(battle[winlose[k]]):
                    for j, card in enumerate(player["cards"]):
                        row[f"{labels[k]}_card_{j+1}_id"] = card["id"]
                        row[f"{labels[k]}_card_{j+1}_level"] = card["level"]
                    tower_card = player["supportCards"][0]
                    row[f"{labels[k]}_tower_card_id"] = tower_card["id"]
                    row[f"{labels[k]}_tower_card_level"] = tower_card["level"]
            
            rows.append(row)
    
    df = pd.DataFrame(rows)
    id_cols = [col for col in df.columns if "_id" in col]
    level_cols = [col for col in df.columns if "_level" in col]
    df[id_cols] = df[id_cols].astype("int32")
    df[level_cols] = df[level_cols].astype("int8")
    
    return df

def get_player_battles(player_id, key):
    if player_id.startswith("#"):
        player_id = player_id[1:]
    url = f"https://api.clashroyale.com/v1/players/%23{player_id}/battlelog"
    return battles_to_dataframe(call_api(url, key).json())

def get_clans(limit = 100, minmembers = 50, minscore = 1000, key = key):
    clan_url = f"https://api.clashroyale.com/v1/clans?minMembers={minmembers}&minScore={minscore}&limit={limit}"
    clan_json = call_api(clan_url, key)
    clans = [i["tag"] for i in clan_json.json()["items"]]
    return clans

def get_members_from_clan(clan, key):
    members_url = f"https://api.clashroyale.com/v1/clans/%23{clan[1:]}/members"
    members_json = call_api(members_url, key)
    members = [i["tag"] for i in members_json.json()["items"]]
    return members

def get_full(file_name, num_clans = 100, key = key, clans_list = None, max_workers = 1):
    if not clans_list:
        clans = get_clans(num_clans, key=key)
    else:
        clans = clans_list
    print(f"Retrieved {len(clans)} clans")
    pd
    players = []
    for c in clans:
        players += get_members_from_clan(c, key)
    players = list(set(players))
    print(f"Retrieved {len(players)} players")
    if max_workers == 1:
        df = get_battles_sequential(players, key, file_name)
    else:
        df = get_battles_parallel(players, key, file_name, max_workers)
    df.to_csv(f"{file_name}.csv", index=False)
    print(f"Saved final df to {file_name}.csv")
    print("Done!")
    return df

def get_battles_sequential(players, key, file_name):
    df = pd.DataFrame()
    for p in range(len(players)):
        print(f"Retrieving battles for player {p}/{len(players)}     ", end="\r")
        try:
            player_df = get_player_battles(players[p], key)
            df = pd.concat([df, player_df])
        except Exception as e:
            print(f"Error retrieving battles for player {p}: {e}")
        if p + 1 %100 == 0:
            df.to_csv(f"{file_name}.csv", index=False)
            print(f"Saved {p} players to {file_name}.csv", end = "\r")
    print(f"Retrieving battles for player {p + 1}/{len(players)}")
    return df

def get_battles_parallel(players, key, file_name, max_workers):
    df_list = []
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        futures = [executor.submit(get_player_battles, player, key) for player in players]
        for i, future in enumerate(as_completed(futures)):
            try:
                player_df = future.result()
                if not player_df.empty:
                    df_list.append(player_df)
                if (i + 1) % 500 == 0:
                    pd.concat(df_list, ignore_index=True).to_csv(f"{file_name}.csv", index=False)
                    print(f"Saved {i + 1} players to {file_name}.csv", end="\r")
            except Exception as e:
                print(f"Error retrieving battles for player: {e}")
    final_df = pd.concat(df_list, ignore_index=True)
    return final_df

# %%
my_id = "ULCYC0UU"
url = f"https://api.clashroyale.com/v1/players/%23{my_id}/battlelog"
url = "https://api.clashroyale.com/v1/clans?maxMembers=30&minMembers=20&minScore=1000&limit=3000"
x = call_api(url, key).json()
x
# Out:
# {'items': [{'tag': '#L2UGJUJ0',
#    'name': '*Starlight*',
#    'type': 'closed',
#    'badgeId': 16000169,
#    'clanScore': 55062,
#    'clanWarTrophies': 1497,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 1015,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#RYQQ80QQ',
#    'name': '0S CRI0LOS',
#    'type': 'open',
#    'badgeId': 16000075,
#    'clanScore': 48110,
#    'clanWarTrophies': 0,
#    'location': {'id': 57000038,
#     'name': 'Brazil',
#     'isCountry': True,
#     'countryCode': 'BR'},
#    'requiredTrophies': 4000,
#    'donationsPerWeek': 1318,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 24},
#   {'tag': '#RQCQG2LR',
#    'name': '10-H',
#    'type': 'open',
#    'badgeId': 16000020,
#    'clanScore': 34983,
#    'clanWarTrophies': 120,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 1035,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#RPRQ9U02',
#    'name': '10/B',
#    'type': 'inviteOnly',
#    'badgeId': 16000030,
#    'clanScore': 44381,
#    'clanWarTrophies': 175,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 201,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#R9VRUPYP',
#    'name': '100% BRASIL',
#    'type': 'open',
#    'badgeId': 16000058,
#    'clanScore': 58049,
#    'clanWarTrophies': 210,
#    'location': {'id': 57000038,
#     'name': 'Brazil',
#     'isCountry': True,
#     'countryCode': 'BR'},
#    'requiredTrophies': 7000,
#    'donationsPerWeek': 2668,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 23},
#   {'tag': '#GLRGQLCL',
#    'name': '123321111',
#    'type': 'inviteOnly',
#    'badgeId': 16000140,
#    'clanScore': 60521,
#    'clanWarTrophies': 160,
#    'location': {'id': 57000017,
#     'name': 'Argentina',
#     'isCountry': True,
#     'countryCode': 'AR'},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 1871,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 25},
#   {'tag': '#GUPUCQUR',
#    'name': '13Divisions',
#    'type': 'open',
#    'badgeId': 16000078,
#    'clanScore': 41865,
#    'clanWarTrophies': 1840,
#    'location': {'id': 57000087,
#     'name': 'France',
#     'isCountry': True,
#     'countryCode': 'FR'},
#    'requiredTrophies': 2000,
#    'donationsPerWeek': 776,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#RL9989CJ',
#    'name': '1899',
#    'type': 'open',
#    'badgeId': 16000074,
#    'clanScore': 46758,
#    'clanWarTrophies': 150,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 274,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 21},
#   {'tag': '#LVJYLU9L',
#    'name': '2 salvadoreños',
#    'type': 'inviteOnly',
#    'badgeId': 16000147,
#    'clanScore': 69440,
#    'clanWarTrophies': 2115,
#    'location': {'id': 57000078,
#     'name': 'El Salvador',
#     'isCountry': True,
#     'countryCode': 'SV'},
#    'requiredTrophies': 7000,
#    'donationsPerWeek': 1242,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 26},
#   {'tag': '#RYLYLYV2',
#    'name': '2-A.',
#    'type': 'closed',
#    'badgeId': 16000150,
#    'clanScore': 48831,
#    'clanWarTrophies': 140,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 710,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#QCLRLQPU',
#    'name': '2.0-PARÁ 091',
#    'type': 'open',
#    'badgeId': 16000058,
#    'clanScore': 33754,
#    'clanWarTrophies': 160,
#    'location': {'id': 57000038,
#     'name': 'Brazil',
#     'isCountry': True,
#     'countryCode': 'BR'},
#    'requiredTrophies': 1000,
#    'donationsPerWeek': 808,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 21},
#   {'tag': '#R2PUJJLR',
#    'name': '205',
#    'type': 'inviteOnly',
#    'badgeId': 16000175,
#    'clanScore': 56970,
#    'clanWarTrophies': 250,
#    'location': {'id': 57000174,
#     'name': 'North Korea',
#     'isCountry': True,
#     'countryCode': 'KP'},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 1284,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 25},
#   {'tag': '#RQC902LG',
#    'name': '2563',
#    'type': 'inviteOnly',
#    'badgeId': 16000124,
#    'clanScore': 39224,
#    'clanWarTrophies': 95,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 320,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#R0VVG0VU',
#    'name': '2GT6',
#    'type': 'inviteOnly',
#    'badgeId': 16000078,
#    'clanScore': 52072,
#    'clanWarTrophies': 516,
#    'location': {'id': 57000087,
#     'name': 'France',
#     'isCountry': True,
#     'countryCode': 'FR'},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 1809,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 23},
#   {'tag': '#GULG829J',
#    'name': '2pa',
#    'type': 'open',
#    'badgeId': 16000001,
#    'clanScore': 38560,
#    'clanWarTrophies': 564,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 498,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 22},
#   {'tag': '#GLRLVY9J',
#    'name': '2v2',
#    'type': 'open',
#    'badgeId': 16000012,
#    'clanScore': 47239,
#    'clanWarTrophies': 585,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 300,
#    'donationsPerWeek': 615,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#RPUC0Q88',
#    'name': '3 Moscagueiros',
#    'type': 'open',
#    'badgeId': 16000142,
#    'clanScore': 46097,
#    'clanWarTrophies': 240,
#    'location': {'id': 57000188,
#     'name': 'Portugal',
#     'isCountry': True,
#     'countryCode': 'PT'},
#    'requiredTrophies': 1300,
#    'donationsPerWeek': 1121,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#RPVU2CQ8',
#    'name': '3dsa',
#    'type': 'open',
#    'badgeId': 16000034,
#    'clanScore': 47281,
#    'clanWarTrophies': 320,
#    'location': {'id': 57000120,
#     'name': 'Italy',
#     'isCountry': True,
#     'countryCode': 'IT'},
#    'requiredTrophies': 3000,
#    'donationsPerWeek': 1125,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#QJUL9Y8G',
#    'name': '4 Fat Guys',
#    'type': 'open',
#    'badgeId': 16000146,
#    'clanScore': 62589,
#    'clanWarTrophies': 480,
#    'location': {'id': 57000249,
#     'name': 'United States',
#     'isCountry': True,
#     'countryCode': 'US'},
#    'requiredTrophies': 7000,
#    'donationsPerWeek': 1100,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#2GVLRGLR',
#    'name': '4FITCLÃ',
#    'type': 'open',
#    'badgeId': 16000010,
#    'clanScore': 65678,
#    'clanWarTrophies': 1725,
#    'location': {'id': 57000038,
#     'name': 'Brazil',
#     'isCountry': True,
#     'countryCode': 'BR'},
#    'requiredTrophies': 7500,
#    'donationsPerWeek': 944,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#RLCQ8UR9',
#    'name': '5 minutes',
#    'type': 'open',
#    'badgeId': 16000028,
#    'clanScore': 37127,
#    'clanWarTrophies': 520,
#    'location': {'id': 57000249,
#     'name': 'United States',
#     'isCountry': True,
#     'countryCode': 'US'},
#    'requiredTrophies': 600,
#    'donationsPerWeek': 840,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 24},
#   {'tag': '#RG02GQRL',
#    'name': '50 Fire Decks',
#    'type': 'open',
#    'badgeId': 16000007,
#    'clanScore': 33677,
#    'clanWarTrophies': 120,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 998,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 22},
#   {'tag': '#U09PYYL',
#    'name': '50 Kings Nic',
#    'type': 'open',
#    'badgeId': 16000003,
#    'clanScore': 59138,
#    'clanWarTrophies': 2263,
#    'location': {'id': 57000169,
#     'name': 'Nicaragua',
#     'isCountry': True,
#     'countryCode': 'NI'},
#    'requiredTrophies': 5000,
#    'donationsPerWeek': 916,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#GUCG8L0R',
#    'name': '505Pinolero4:20',
#    'type': 'inviteOnly',
#    'badgeId': 16000171,
#    'clanScore': 64789,
#    'clanWarTrophies': 1888,
#    'location': {'id': 57000169,
#     'name': 'Nicaragua',
#     'isCountry': True,
#     'countryCode': 'NI'},
#    'requiredTrophies': 5000,
#    'donationsPerWeek': 550,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 24},
#   {'tag': '#GQG200YJ',
#    'name': '52 CB',
#    'type': 'inviteOnly',
#    'badgeId': 16000072,
#    'clanScore': 41704,
#    'clanWarTrophies': 70,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 4000,
#    'donationsPerWeek': 952,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#RY2YQVPL',
#    'name': '63rdgang',
#    'type': 'open',
#    'badgeId': 16000157,
#    'clanScore': 49054,
#    'clanWarTrophies': 80,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 781,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 22},
#   {'tag': '#R98QGQU0',
#    'name': '67 big booms',
#    'type': 'open',
#    'badgeId': 16000035,
#    'clanScore': 19804,
#    'clanWarTrophies': 100,
#    'location': {'id': 57000047,
#     'name': 'Canada',
#     'isCountry': True,
#     'countryCode': 'CA'},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 454,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 22},
#   {'tag': '#R8V0RPYP',
#    'name': '85Turn',
#    'type': 'open',
#    'badgeId': 16000165,
#    'clanScore': 46098,
#    'clanWarTrophies': 100,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 1236,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 21},
#   {'tag': '#RQYCQ9J2',
#    'name': '9-C',
#    'type': 'open',
#    'badgeId': 16000029,
#    'clanScore': 37529,
#    'clanWarTrophies': 166,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 461,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 22},
#   {'tag': '#QRVC0LVJ',
#    'name': '911 Flight Crew',
#    'type': 'open',
#    'badgeId': 16000002,
#    'clanScore': 53535,
#    'clanWarTrophies': 987,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 1300,
#    'donationsPerWeek': 911,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 21},
#   {'tag': '#QYCUCRPP',
#    'name': '_NERCI_',
#    'type': 'open',
#    'badgeId': 16000072,
#    'clanScore': 59127,
#    'clanWarTrophies': 1410,
#    'location': {'id': 57000153,
#     'name': 'Mexico',
#     'isCountry': True,
#     'countryCode': 'MX'},
#    'requiredTrophies': 4300,
#    'donationsPerWeek': 708,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 22},
#   {'tag': '#R8JRYG99',
#    'name': 'A PELUCHE',
#    'type': 'open',
#    'badgeId': 16000075,
#    'clanScore': 50083,
#    'clanWarTrophies': 160,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 1627,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 25},
#   {'tag': '#RQRQY2PV',
#    'name': 'A.N.T Army',
#    'type': 'open',
#    'badgeId': 16000029,
#    'clanScore': 45205,
#    'clanWarTrophies': 135,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 857,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#R8GQQJ2P',
#    'name': 'A.T.P',
#    'type': 'inviteOnly',
#    'badgeId': 16000161,
#    'clanScore': 52311,
#    'clanWarTrophies': 265,
#    'location': {'id': 57000002, 'name': 'South America', 'isCountry': False},
#    'requiredTrophies': 2000,
#    'donationsPerWeek': 1070,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 22},
#   {'tag': '#R99UU28J',
#    'name': 'ABUELA BELLACA',
#    'type': 'open',
#    'badgeId': 16000125,
#    'clanScore': 51761,
#    'clanWarTrophies': 635,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 3000,
#    'donationsPerWeek': 718,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 21},
#   {'tag': '#R9VVUP0U',
#    'name': 'Acereros royal',
#    'type': 'open',
#    'badgeId': 16000042,
#    'clanScore': 49784,
#    'clanWarTrophies': 940,
#    'location': {'id': 57000218,
#     'name': 'Spain',
#     'isCountry': True,
#     'countryCode': 'ES'},
#    'requiredTrophies': 3000,
#    'donationsPerWeek': 538,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#QCUQ8Q0P',
#    'name': 'Acka',
#    'type': 'open',
#    'badgeId': 16000167,
#    'clanScore': 50302,
#    'clanWarTrophies': 100,
#    'location': {'id': 57000094,
#     'name': 'Germany',
#     'isCountry': True,
#     'countryCode': 'DE'},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 582,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 21},
#   {'tag': '#R9JG2Y88',
#    'name': 'aguante jamaica',
#    'type': 'open',
#    'badgeId': 16000091,
#    'clanScore': 33956,
#    'clanWarTrophies': 220,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 300,
#    'donationsPerWeek': 996,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 26},
#   {'tag': '#R88GVQPL',
#    'name': 'aguante messi',
#    'type': 'open',
#    'badgeId': 16000043,
#    'clanScore': 42595,
#    'clanWarTrophies': 340,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 1041,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 22},
#   {'tag': '#R2VUL008',
#    'name': 'AH PRINCESOS',
#    'type': 'open',
#    'badgeId': 16000029,
#    'clanScore': 49833,
#    'clanWarTrophies': 375,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 552,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 24},
#   {'tag': '#R8PCUVQV',
#    'name': 'Al barro',
#    'type': 'open',
#    'badgeId': 16000159,
#    'clanScore': 58880,
#    'clanWarTrophies': 310,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 5000,
#    'donationsPerWeek': 376,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 21},
#   {'tag': '#GLPUPRUJ',
#    'name': 'Aleans',
#    'type': 'open',
#    'badgeId': 16000098,
#    'clanScore': 39936,
#    'clanWarTrophies': 1259,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 2000,
#    'donationsPerWeek': 444,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 21},
#   {'tag': '#R8JYY9PQ',
#    'name': 'ALKAEDA',
#    'type': 'open',
#    'badgeId': 16000162,
#    'clanScore': 43479,
#    'clanWarTrophies': 210,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 790,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#2R9R08UU',
#    'name': 'Alpes Suínos',
#    'type': 'open',
#    'badgeId': 16000123,
#    'clanScore': 66987,
#    'clanWarTrophies': 2622,
#    'location': {'id': 57000038,
#     'name': 'Brazil',
#     'isCountry': True,
#     'countryCode': 'BR'},
#    'requiredTrophies': 7000,
#    'donationsPerWeek': 1888,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 24},
#   {'tag': '#RYQG9VUP',
#    'name': 'Alphas Pack',
#    'type': 'open',
#    'badgeId': 16000095,
#    'clanScore': 46438,
#    'clanWarTrophies': 60,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 525,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#QRR098UG',
#    'name': 'AMEGAKURE ROYAL',
#    'type': 'open',
#    'badgeId': 16000145,
#    'clanScore': 62951,
#    'clanWarTrophies': 1190,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 7000,
#    'donationsPerWeek': 972,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 22},
#   {'tag': '#R8CURRG0',
#    'name': 'AMIZADE CPX',
#    'type': 'open',
#    'badgeId': 16000058,
#    'clanScore': 48832,
#    'clanWarTrophies': 1280,
#    'location': {'id': 57000038,
#     'name': 'Brazil',
#     'isCountry': True,
#     'countryCode': 'BR'},
#    'requiredTrophies': 3000,
#    'donationsPerWeek': 1218,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 21},
#   {'tag': '#R8GRUCJJ',
#    'name': 'amoomgus',
#    'type': 'open',
#    'badgeId': 16000135,
#    'clanScore': 35987,
#    'clanWarTrophies': 85,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 950,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#LC92GY80',
#    'name': 'Anashey',
#    'type': 'open',
#    'badgeId': 16000112,
#    'clanScore': 47487,
#    'clanWarTrophies': 1044,
#    'location': {'id': 57000002, 'name': 'South America', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 612,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#QV2PUC8G',
#    'name': 'anciões_of_clas',
#    'type': 'open',
#    'badgeId': 16000058,
#    'clanScore': 24467,
#    'clanWarTrophies': 118,
#    'location': {'id': 57000038,
#     'name': 'Brazil',
#     'isCountry': True,
#     'countryCode': 'BR'},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 579,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 21},
#   {'tag': '#RPGYVQCU',
#    'name': 'Anderson Tribe',
#    'type': 'open',
#    'badgeId': 16000136,
#    'clanScore': 37401,
#    'clanWarTrophies': 60,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 1118,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#R8C9VLG8',
#    'name': 'AndresMorin',
#    'type': 'inviteOnly',
#    'badgeId': 16000128,
#    'clanScore': 46402,
#    'clanWarTrophies': 250,
#    'location': {'id': 57000001, 'name': 'North America', 'isCountry': False},
#    'requiredTrophies': 1300,
#    'donationsPerWeek': 852,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#QUQ8C2VR',
#    'name': 'ANDROID ELITE',
#    'type': 'open',
#    'badgeId': 16000058,
#    'clanScore': 54675,
#    'clanWarTrophies': 2619,
#    'location': {'id': 57000038,
#     'name': 'Brazil',
#     'isCountry': True,
#     'countryCode': 'BR'},
#    'requiredTrophies': 3300,
#    'donationsPerWeek': 891,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 21},
#   {'tag': '#RYJ0PL9Q',
#    'name': 'Angel.B luv erz',
#    'type': 'inviteOnly',
#    'badgeId': 16000010,
#    'clanScore': 52340,
#    'clanWarTrophies': 50,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 986,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 24},
#   {'tag': '#RY0CYV9Y',
#    'name': 'Anti amapolas',
#    'type': 'open',
#    'badgeId': 16000025,
#    'clanScore': 40153,
#    'clanWarTrophies': 180,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 326,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 23},
#   {'tag': '#R8G88L0V',
#    'name': 'Anti-Xbow',
#    'type': 'open',
#    'badgeId': 16000122,
#    'clanScore': 61723,
#    'clanWarTrophies': 280,
#    'location': {'id': 57000001, 'name': 'North America', 'isCountry': False},
#    'requiredTrophies': 2300,
#    'donationsPerWeek': 1205,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 24},
#   {'tag': '#GGQVQ8UC',
#    'name': 'Anticuribots2.0',
#    'type': 'open',
#    'badgeId': 16000028,
#    'clanScore': 63072,
#    'clanWarTrophies': 1680,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 960,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 23},
#   {'tag': '#RYYRYLY9',
#    'name': 'Antiguatonas',
#    'type': 'open',
#    'badgeId': 16000142,
#    'clanScore': 34964,
#    'clanWarTrophies': 0,
#    'location': {'id': 57000055,
#     'name': 'Chile',
#     'isCountry': True,
#     'countryCode': 'CL'},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 394,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 21},
#   {'tag': '#QU0UGRYU',
#    'name': 'apocalypseForce',
#    'type': 'open',
#    'badgeId': 16000015,
#    'clanScore': 53700,
#    'clanWarTrophies': 1935,
#    'location': {'id': 57000249,
#     'name': 'United States',
#     'isCountry': True,
#     'countryCode': 'US'},
#    'requiredTrophies': 2000,
#    'donationsPerWeek': 1554,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 21},
#   {'tag': '#RYYPU2QP',
#    'name': 'arg competitivo',
#    'type': 'open',
#    'badgeId': 16000010,
#    'clanScore': 39889,
#    'clanWarTrophies': 140,
#    'location': {'id': 57000017,
#     'name': 'Argentina',
#     'isCountry': True,
#     'countryCode': 'AR'},
#    'requiredTrophies': 1300,
#    'donationsPerWeek': 1290,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 23},
#   {'tag': '#QC9VU0UG',
#    'name': 'ARG TB',
#    'type': 'closed',
#    'badgeId': 16000063,
#    'clanScore': 63518,
#    'clanWarTrophies': 300,
#    'location': {'id': 57000017,
#     'name': 'Argentina',
#     'isCountry': True,
#     'countryCode': 'AR'},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 944,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 22},
#   {'tag': '#G2V90JUG',
#    'name': 'ARGENTINA',
#    'type': 'open',
#    'badgeId': 16000142,
#    'clanScore': 54502,
#    'clanWarTrophies': 1403,
#    'location': {'id': 57000017,
#     'name': 'Argentina',
#     'isCountry': True,
#     'countryCode': 'AR'},
#    'requiredTrophies': 7000,
#    'donationsPerWeek': 818,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 23},
#   {'tag': '#GY2QQQ9C',
#    'name': 'Argento Puro',
#    'type': 'open',
#    'badgeId': 16000029,
#    'clanScore': 64632,
#    'clanWarTrophies': 2783,
#    'location': {'id': 57000017,
#     'name': 'Argentina',
#     'isCountry': True,
#     'countryCode': 'AR'},
#    'requiredTrophies': 7500,
#    'donationsPerWeek': 1598,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 24},
#   {'tag': '#9C8J0RUJ',
#    'name': 'Armagh Mafia',
#    'type': 'open',
#    'badgeId': 16000052,
#    'clanScore': 60585,
#    'clanWarTrophies': 2280,
#    'location': {'id': 57000248,
#     'name': 'United Kingdom',
#     'isCountry': True,
#     'countryCode': 'GB'},
#    'requiredTrophies': 3600,
#    'donationsPerWeek': 666,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 21},
#   {'tag': '#QP88CJPJ',
#    'name': 'ARMSTRONG',
#    'type': 'open',
#    'badgeId': 16000164,
#    'clanScore': 64695,
#    'clanWarTrophies': 3155,
#    'location': {'id': 57000002, 'name': 'South America', 'isCountry': False},
#    'requiredTrophies': 6000,
#    'donationsPerWeek': 1219,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 23},
#   {'tag': '#LR0UJ2PQ',
#    'name': 'Asintomáticos',
#    'type': 'open',
#    'badgeId': 16000091,
#    'clanScore': 35820,
#    'clanWarTrophies': 1805,
#    'location': {'id': 57000055,
#     'name': 'Chile',
#     'isCountry': True,
#     'countryCode': 'CL'},
#    'requiredTrophies': 2000,
#    'donationsPerWeek': 525,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#GUVGQVL8',
#    'name': 'asm',
#    'type': 'open',
#    'badgeId': 16000010,
#    'clanScore': 53085,
#    'clanWarTrophies': 260,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 1032,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 24},
#   {'tag': '#LRGULY29',
#    'name': 'ASSASSINS_Crew',
#    'type': 'open',
#    'badgeId': 16000009,
#    'clanScore': 57517,
#    'clanWarTrophies': 1402,
#    'location': {'id': 57000078,
#     'name': 'El Salvador',
#     'isCountry': True,
#     'countryCode': 'SV'},
#    'requiredTrophies': 2600,
#    'donationsPerWeek': 384,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#GC88CJ0Y',
#    'name': 'At One Point',
#    'type': 'open',
#    'badgeId': 16000143,
#    'clanScore': 38213,
#    'clanWarTrophies': 244,
#    'location': {'id': 57000249,
#     'name': 'United States',
#     'isCountry': True,
#     'countryCode': 'US'},
#    'requiredTrophies': 600,
#    'donationsPerWeek': 716,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#GUQ8LGRY',
#    'name': 'Atarax',
#    'type': 'inviteOnly',
#    'badgeId': 16000131,
#    'clanScore': 62550,
#    'clanWarTrophies': 1900,
#    'location': {'id': 57000087,
#     'name': 'France',
#     'isCountry': True,
#     'countryCode': 'FR'},
#    'requiredTrophies': 5000,
#    'donationsPerWeek': 1000,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#LJ0QP09L',
#    'name': 'Athsm13épw',
#    'type': 'open',
#    'badgeId': 16000002,
#    'clanScore': 39955,
#    'clanWarTrophies': 1321,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 1012,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 22},
#   {'tag': '#RQV8UUCL',
#    'name': 'atlanta yn hub',
#    'type': 'inviteOnly',
#    'badgeId': 16000108,
#    'clanScore': 61304,
#    'clanWarTrophies': 120,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 3300,
#    'donationsPerWeek': 2480,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 25},
#   {'tag': '#RYG0GPC8',
#    'name': 'aura..',
#    'type': 'open',
#    'badgeId': 16000128,
#    'clanScore': 45850,
#    'clanWarTrophies': 100,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 1221,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 21},
#   {'tag': '#RQ2VLUVC',
#    'name': 'Autisten',
#    'type': 'open',
#    'badgeId': 16000171,
#    'clanScore': 49115,
#    'clanWarTrophies': 120,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 438,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 23},
#   {'tag': '#QG2JGYC9',
#    'name': 'Avengers',
#    'type': 'open',
#    'badgeId': 16000029,
#    'clanScore': 63215,
#    'clanWarTrophies': 2565,
#    'location': {'id': 57000038,
#     'name': 'Brazil',
#     'isCountry': True,
#     'countryCode': 'BR'},
#    'requiredTrophies': 5500,
#    'donationsPerWeek': 1643,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 24},
#   {'tag': '#RQUCGY98',
#    'name': 'AYRI FC',
#    'type': 'inviteOnly',
#    'badgeId': 16000080,
#    'clanScore': 53325,
#    'clanWarTrophies': 60,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 1294,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#92Y9QGJU',
#    'name': 'Azteclash Mx',
#    'type': 'open',
#    'badgeId': 16000167,
#    'clanScore': 65378,
#    'clanWarTrophies': 2455,
#    'location': {'id': 57000001, 'name': 'North America', 'isCountry': False},
#    'requiredTrophies': 3300,
#    'donationsPerWeek': 774,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 24},
#   {'tag': '#R8CGP8CQ',
#    'name': 'AZTLAN',
#    'type': 'inviteOnly',
#    'badgeId': 16000081,
#    'clanScore': 38691,
#    'clanWarTrophies': 124,
#    'location': {'id': 57000153,
#     'name': 'Mexico',
#     'isCountry': True,
#     'countryCode': 'MX'},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 2800,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#RPGPLYPU',
#    'name': 'AðElska',
#    'type': 'open',
#    'badgeId': 16000028,
#    'clanScore': 58086,
#    'clanWarTrophies': 340,
#    'location': {'id': 57000001, 'name': 'North America', 'isCountry': False},
#    'requiredTrophies': 4000,
#    'donationsPerWeek': 1046,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 22},
#   {'tag': '#QJGC8280',
#    'name': 'AÑAS FIÑOS',
#    'type': 'open',
#    'badgeId': 16000160,
#    'clanScore': 54821,
#    'clanWarTrophies': 620,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 1300,
#    'donationsPerWeek': 1066,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 23},
#   {'tag': '#Q2V0QV0P',
#    'name': 'B Y R EL FENIX',
#    'type': 'open',
#    'badgeId': 16000107,
#    'clanScore': 55363,
#    'clanWarTrophies': 2250,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 300,
#    'donationsPerWeek': 886,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 21},
#   {'tag': '#RG20LVJ2',
#    'name': 'BA Clan',
#    'type': 'open',
#    'badgeId': 16000012,
#    'clanScore': 45447,
#    'clanWarTrophies': 100,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 1032,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 24},
#   {'tag': '#QYC2JC82',
#    'name': 'Babybooh',
#    'type': 'open',
#    'badgeId': 16000064,
#    'clanScore': 53206,
#    'clanWarTrophies': 2250,
#    'location': {'id': 57000075,
#     'name': 'Dominican Republic',
#     'isCountry': True,
#     'countryCode': 'DO'},
#    'requiredTrophies': 4000,
#    'donationsPerWeek': 704,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 22},
#   {'tag': '#R8RPY99L',
#    'name': 'Bad Boys',
#    'type': 'open',
#    'badgeId': 16000024,
#    'clanScore': 38590,
#    'clanWarTrophies': 10,
#    'location': {'id': 57000038,
#     'name': 'Brazil',
#     'isCountry': True,
#     'countryCode': 'BR'},
#    'requiredTrophies': 2000,
#    'donationsPerWeek': 733,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 22},
#   {'tag': '#RQVVL0G0',
#    'name': 'BAGGROS 187',
#    'type': 'open',
#    'badgeId': 16000087,
#    'clanScore': 57595,
#    'clanWarTrophies': 60,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 729,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#GCCCJJPC',
#    'name': 'BALLZ',
#    'type': 'inviteOnly',
#    'badgeId': 16000106,
#    'clanScore': 54828,
#    'clanWarTrophies': 955,
#    'location': {'id': 57000170,
#     'name': 'Niger',
#     'isCountry': True,
#     'countryCode': 'NE'},
#    'requiredTrophies': 7500,
#    'donationsPerWeek': 423,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 22},
#   {'tag': '#GQQ0UC9J',
#    'name': 'ballz',
#    'type': 'inviteOnly',
#    'badgeId': 16000170,
#    'clanScore': 51238,
#    'clanWarTrophies': 150,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 982,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 23},
#   {'tag': '#RQYV29VQ',
#    'name': 'BAMBOO',
#    'type': 'inviteOnly',
#    'badgeId': 16000137,
#    'clanScore': 45945,
#    'clanWarTrophies': 260,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 665,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 26},
#   {'tag': '#PUYC9Y88',
#    'name': 'Bando de Loucos',
#    'type': 'open',
#    'badgeId': 16000029,
#    'clanScore': 62709,
#    'clanWarTrophies': 2045,
#    'location': {'id': 57000038,
#     'name': 'Brazil',
#     'isCountry': True,
#     'countryCode': 'BR'},
#    'requiredTrophies': 6000,
#    'donationsPerWeek': 790,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 21},
#   {'tag': '#GLQLVJ9U',
#    'name': 'Barack Obombers',
#    'type': 'open',
#    'badgeId': 16000154,
#    'clanScore': 60900,
#    'clanWarTrophies': 1698,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 4600,
#    'donationsPerWeek': 1110,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 27},
#   {'tag': '#R99Q8VGY',
#    'name': 'Barbaian Sigmas',
#    'type': 'inviteOnly',
#    'badgeId': 16000005,
#    'clanScore': 53422,
#    'clanWarTrophies': 420,
#    'location': {'id': 57000249,
#     'name': 'United States',
#     'isCountry': True,
#     'countryCode': 'US'},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 948,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 27},
#   {'tag': '#QCQGGU9L',
#    'name': 'Baretaland',
#    'type': 'open',
#    'badgeId': 16000171,
#    'clanScore': 52948,
#    'clanWarTrophies': 185,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 649,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 21},
#   {'tag': '#GV9L9QQJ',
#    'name': 'BARRA CLASH',
#    'type': 'inviteOnly',
#    'badgeId': 16000058,
#    'clanScore': 39188,
#    'clanWarTrophies': 180,
#    'location': {'id': 57000038,
#     'name': 'Brazil',
#     'isCountry': True,
#     'countryCode': 'BR'},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 1879,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 21},
#   {'tag': '#RY88QQ8R',
#    'name': 'Barrel of Jews',
#    'type': 'inviteOnly',
#    'badgeId': 16000154,
#    'clanScore': 36725,
#    'clanWarTrophies': 240,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 1000,
#    'donationsPerWeek': 734,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#R8P82QR8',
#    'name': 'bata eu',
#    'type': 'open',
#    'badgeId': 16000134,
#    'clanScore': 49796,
#    'clanWarTrophies': 234,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 1060,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#GLY2JR80',
#    'name': 'Bateil mecatron',
#    'type': 'open',
#    'badgeId': 16000008,
#    'clanScore': 48819,
#    'clanWarTrophies': 372,
#    'location': {'id': 57000000, 'name': 'Europe', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 531,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#R82Y9QR0',
#    'name': 'bbl buddies',
#    'type': 'inviteOnly',
#    'badgeId': 16000170,
#    'clanScore': 54801,
#    'clanWarTrophies': 540,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 3000,
#    'donationsPerWeek': 1216,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 24},
#   {'tag': '#GGCLGYCP',
#    'name': 'BBN™',
#    'type': 'open',
#    'badgeId': 16000002,
#    'clanScore': 51739,
#    'clanWarTrophies': 1545,
#    'location': {'id': 57000249,
#     'name': 'United States',
#     'isCountry': True,
#     'countryCode': 'US'},
#    'requiredTrophies': 3000,
#    'donationsPerWeek': 1140,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 23},
#   {'tag': '#QRJVVULG',
#    'name': 'BBVA',
#    'type': 'open',
#    'badgeId': 16000165,
#    'clanScore': 38845,
#    'clanWarTrophies': 1890,
#    'location': {'id': 57000153,
#     'name': 'Mexico',
#     'isCountry': True,
#     'countryCode': 'MX'},
#    'requiredTrophies': 1300,
#    'donationsPerWeek': 1182,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 21},
#   {'tag': '#RYPJQG8G',
#    'name': 'BDG',
#    'type': 'open',
#    'badgeId': 16000076,
#    'clanScore': 47478,
#    'clanWarTrophies': 160,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 1164,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 22},
#   {'tag': '#GQC8GY0U',
#    'name': 'bduh minions',
#    'type': 'inviteOnly',
#    'badgeId': 16000107,
#    'clanScore': 57675,
#    'clanWarTrophies': 95,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 3300,
#    'donationsPerWeek': 1476,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 23},
#   {'tag': '#G2RYQVUU',
#    'name': 'bean69',
#    'type': 'inviteOnly',
#    'badgeId': 16000077,
#    'clanScore': 44505,
#    'clanWarTrophies': 647,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 4000,
#    'donationsPerWeek': 356,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 21},
#   {'tag': '#R8RG9J0L',
#    'name': 'Beannsssss',
#    'type': 'open',
#    'badgeId': 16000012,
#    'clanScore': 55523,
#    'clanWarTrophies': 140,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 1230,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 24},
#   {'tag': '#R9YPJCUQ',
#    'name': 'Bear Hunters',
#    'type': 'open',
#    'badgeId': 16000035,
#    'clanScore': 59660,
#    'clanWarTrophies': 944,
#    'location': {'id': 57000249,
#     'name': 'United States',
#     'isCountry': True,
#     'countryCode': 'US'},
#    'requiredTrophies': 5000,
#    'donationsPerWeek': 279,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#RQJP0UVJ',
#    'name': 'beaver clan',
#    'type': 'open',
#    'badgeId': 16000139,
#    'clanScore': 52157,
#    'clanWarTrophies': 140,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 3000,
#    'donationsPerWeek': 804,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 25},
#   {'tag': '#RY2QG920',
#    'name': 'beddan',
#    'type': 'open',
#    'badgeId': 16000002,
#    'clanScore': 53004,
#    'clanWarTrophies': 300,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 964,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 26},
#   {'tag': '#RPCY80YP',
#    'name': 'Beef Rap Barcel',
#    'type': 'open',
#    'badgeId': 16000122,
#    'clanScore': 56436,
#    'clanWarTrophies': 205,
#    'location': {'id': 57000174,
#     'name': 'North Korea',
#     'isCountry': True,
#     'countryCode': 'KP'},
#    'requiredTrophies': 3000,
#    'donationsPerWeek': 2184,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 27},
#   {'tag': '#R2VUP2UG',
#    'name': 'BeerLeaugers',
#    'type': 'open',
#    'badgeId': 16000120,
#    'clanScore': 50590,
#    'clanWarTrophies': 497,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 1050,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#R9YL9CJC',
#    'name': 'ben gave hawk',
#    'type': 'open',
#    'badgeId': 16000179,
#    'clanScore': 54149,
#    'clanWarTrophies': 311,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 892,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 26},
#   {'tag': '#R99YYUPL',
#    'name': 'bertrand',
#    'type': 'open',
#    'badgeId': 16000154,
#    'clanScore': 46443,
#    'clanWarTrophies': 100,
#    'location': {'id': 57000001, 'name': 'North America', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 816,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 22},
#   {'tag': '#P08CC22J',
#    'name': 'Best of Sparta!',
#    'type': 'open',
#    'badgeId': 16000058,
#    'clanScore': 58687,
#    'clanWarTrophies': 2225,
#    'location': {'id': 57000038,
#     'name': 'Brazil',
#     'isCountry': True,
#     'countryCode': 'BR'},
#    'requiredTrophies': 3600,
#    'donationsPerWeek': 864,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 21},
#   {'tag': '#RQQ0LGLU',
#    'name': 'Bestias de la u',
#    'type': 'open',
#    'badgeId': 16000035,
#    'clanScore': 59431,
#    'clanWarTrophies': 300,
#    'location': {'id': 57000002, 'name': 'South America', 'isCountry': False},
#    'requiredTrophies': 6500,
#    'donationsPerWeek': 482,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 24},
#   {'tag': '#QJUGC8JP',
#    'name': 'Big backs',
#    'type': 'inviteOnly',
#    'badgeId': 16000154,
#    'clanScore': 50323,
#    'clanWarTrophies': 340,
#    'location': {'id': 57000001, 'name': 'North America', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 738,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 23},
#   {'tag': '#QLLJ2PJ8',
#    'name': 'Big bang bommer',
#    'type': 'inviteOnly',
#    'badgeId': 16000028,
#    'clanScore': 57709,
#    'clanWarTrophies': 1827,
#    'location': {'id': 57000001, 'name': 'North America', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 1203,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 25},
#   {'tag': '#QGVR2CCY',
#    'name': 'big boyz',
#    'type': 'open',
#    'badgeId': 16000136,
#    'clanScore': 52521,
#    'clanWarTrophies': 1157,
#    'location': {'id': 57000001, 'name': 'North America', 'isCountry': False},
#    'requiredTrophies': 3000,
#    'donationsPerWeek': 1402,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 22},
#   {'tag': '#R2JCRPGR',
#    'name': 'big bug bus',
#    'type': 'open',
#    'badgeId': 16000024,
#    'clanScore': 50464,
#    'clanWarTrophies': 1119,
#    'location': {'id': 57000001, 'name': 'North America', 'isCountry': False},
#    'requiredTrophies': 6500,
#    'donationsPerWeek': 782,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#RPCRYLYY',
#    'name': 'Big Fishy',
#    'type': 'open',
#    'badgeId': 16000164,
#    'clanScore': 48293,
#    'clanWarTrophies': 90,
#    'location': {'id': 57000249,
#     'name': 'United States',
#     'isCountry': True,
#     'countryCode': 'US'},
#    'requiredTrophies': 3300,
#    'donationsPerWeek': 1194,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 21},
#   {'tag': '#R0YGGLGJ',
#    'name': 'Big Meaty Boys',
#    'type': 'open',
#    'badgeId': 16000149,
#    'clanScore': 65395,
#    'clanWarTrophies': 1380,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 7500,
#    'donationsPerWeek': 1118,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 22},
#   {'tag': '#R0V9URCP',
#    'name': 'Big Nerds',
#    'type': 'inviteOnly',
#    'badgeId': 16000029,
#    'clanScore': 45533,
#    'clanWarTrophies': 516,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 956,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 23},
#   {'tag': '#QUQPRCYL',
#    'name': 'big_toes69',
#    'type': 'open',
#    'badgeId': 16000170,
#    'clanScore': 41386,
#    'clanWarTrophies': 0,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 1121,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 22},
#   {'tag': '#R8VU2YRJ',
#    'name': 'Bio 3rd Period',
#    'type': 'open',
#    'badgeId': 16000000,
#    'clanScore': 45216,
#    'clanWarTrophies': 60,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 625,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#RYYC2VUY',
#    'name': 'Bishop Balls',
#    'type': 'inviteOnly',
#    'badgeId': 16000102,
#    'clanScore': 47236,
#    'clanWarTrophies': 160,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 1186,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#QCGG0G9L',
#    'name': 'Black Ice',
#    'type': 'open',
#    'badgeId': 16000168,
#    'clanScore': 47464,
#    'clanWarTrophies': 500,
#    'location': {'id': 57000001, 'name': 'North America', 'isCountry': False},
#    'requiredTrophies': 1600,
#    'donationsPerWeek': 572,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 21},
#   {'tag': '#RY9LJG80',
#    'name': 'BLACK SLAVES',
#    'type': 'open',
#    'badgeId': 16000027,
#    'clanScore': 57288,
#    'clanWarTrophies': 260,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 3000,
#    'donationsPerWeek': 625,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#Q0RYCJ',
#    'name': 'blacksuns',
#    'type': 'open',
#    'badgeId': 16000024,
#    'clanScore': 64324,
#    'clanWarTrophies': 2055,
#    'location': {'id': 57000249,
#     'name': 'United States',
#     'isCountry': True,
#     'countryCode': 'US'},
#    'requiredTrophies': 5500,
#    'donationsPerWeek': 634,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 26},
#   {'tag': '#QPPUVLG0',
#    'name': 'blood for blood',
#    'type': 'open',
#    'badgeId': 16000124,
#    'clanScore': 43576,
#    'clanWarTrophies': 1962,
#    'location': {'id': 57000038,
#     'name': 'Brazil',
#     'isCountry': True,
#     'countryCode': 'BR'},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 1734,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 21},
#   {'tag': '#Y0RL0VGG',
#    'name': 'Blue Wolves',
#    'type': 'inviteOnly',
#    'badgeId': 16000122,
#    'clanScore': 41424,
#    'clanWarTrophies': 1671,
#    'location': {'id': 57000249,
#     'name': 'United States',
#     'isCountry': True,
#     'countryCode': 'US'},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 710,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 24},
#   {'tag': '#GGR2Y0UL',
#    'name': 'bobbykuizon',
#    'type': 'open',
#    'badgeId': 16000019,
#    'clanScore': 48439,
#    'clanWarTrophies': 631,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 437,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 22},
#   {'tag': '#RY0QVGRL',
#    'name': 'boi',
#    'type': 'open',
#    'badgeId': 16000140,
#    'clanScore': 39833,
#    'clanWarTrophies': 110,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 564,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 21},
#   {'tag': '#RY89CC8G',
#    'name': 'bolsonaro 2026',
#    'type': 'open',
#    'badgeId': 16000058,
#    'clanScore': 47610,
#    'clanWarTrophies': 300,
#    'location': {'id': 57000038,
#     'name': 'Brazil',
#     'isCountry': True,
#     'countryCode': 'BR'},
#    'requiredTrophies': 3000,
#    'donationsPerWeek': 1500,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 22},
#   {'tag': '#R8Q99GC2',
#    'name': 'BombardeoaPeru',
#    'type': 'open',
#    'badgeId': 16000067,
#    'clanScore': 49941,
#    'clanWarTrophies': 104,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 1373,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 21},
#   {'tag': '#R0C9LULG',
#    'name': 'bomboclap',
#    'type': 'open',
#    'badgeId': 16000073,
#    'clanScore': 51530,
#    'clanWarTrophies': 1493,
#    'location': {'id': 57000259,
#     'name': 'Zambia',
#     'isCountry': True,
#     'countryCode': 'ZM'},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 830,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 22},
#   {'tag': '#RLGQVRRL',
#    'name': 'Bone Crown',
#    'type': 'open',
#    'badgeId': 16000024,
#    'clanScore': 58503,
#    'clanWarTrophies': 805,
#    'location': {'id': 57000001, 'name': 'North America', 'isCountry': False},
#    'requiredTrophies': 3000,
#    'donationsPerWeek': 648,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#R082RVQC',
#    'name': 'Boom Boom Room',
#    'type': 'open',
#    'badgeId': 16000166,
#    'clanScore': 49358,
#    'clanWarTrophies': 1866,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 1600,
#    'donationsPerWeek': 437,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#QCV9JV9V',
#    'name': 'BOPE',
#    'type': 'closed',
#    'badgeId': 16000025,
#    'clanScore': 59135,
# ...
#    'members': 24},
#   {'tag': '#QUQG0JQQ',
#    'name': 'ŠTRUMPFOVI',
#    'type': 'open',
#    'badgeId': 16000029,
#    'clanScore': 51109,
#    'clanWarTrophies': 894,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 786,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 21},
#   {'tag': '#LV8YJVC8',
#    'name': 'Гачи family',
#    'type': 'inviteOnly',
#    'badgeId': 16000072,
#    'clanScore': 53962,
#    'clanWarTrophies': 1460,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 476,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#QUQLVGUG',
#    'name': 'гули нубики',
#    'type': 'inviteOnly',
#    'badgeId': 16000016,
#    'clanScore': 48691,
#    'clanWarTrophies': 1330,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 4000,
#    'donationsPerWeek': 492,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 22},
#   {'tag': '#RPJUQ08Q',
#    'name': 'зернадцать',
#    'type': 'open',
#    'badgeId': 16000072,
#    'clanScore': 58648,
#    'clanWarTrophies': 250,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 4000,
#    'donationsPerWeek': 1363,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 25},
#   {'tag': '#GYR0V0VG',
#    'name': 'Клан:  #GYR0V0VG',
#    'type': 'open',
#    'badgeId': 16000134,
#    'clanScore': 38680,
#    'clanWarTrophies': 703,
#    'location': {'id': 57000193,
#     'name': 'Russia',
#     'isCountry': True,
#     'countryCode': 'RU'},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 450,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#QUC9YJR8',
#    'name': 'КЛЫР',
#    'type': 'open',
#    'badgeId': 16000155,
#    'clanScore': 47809,
#    'clanWarTrophies': 70,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 839,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 22},
#   {'tag': '#R9LVQ9RQ',
#    'name': 'Корни ATa',
#    'type': 'open',
#    'badgeId': 16000033,
#    'clanScore': 44314,
#    'clanWarTrophies': 647,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 553,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#R8JJ09RG',
#    'name': 'крутые',
#    'type': 'open',
#    'badgeId': 16000072,
#    'clanScore': 44128,
#    'clanWarTrophies': 60,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 1258,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#R8GL0UCR',
#    'name': 'МЦК КИП 45',
#    'type': 'open',
#    'badgeId': 16000030,
#    'clanScore': 48132,
#    'clanWarTrophies': 175,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 2000,
#    'donationsPerWeek': 967,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 24},
#   {'tag': '#QL2V0Q89',
#    'name': 'не петушки',
#    'type': 'open',
#    'badgeId': 16000154,
#    'clanScore': 51521,
#    'clanWarTrophies': 1561,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 2000,
#    'donationsPerWeek': 944,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 23},
#   {'tag': '#QUR9VP2J',
#    'name': 'Негоы',
#    'type': 'open',
#    'badgeId': 16000009,
#    'clanScore': 46487,
#    'clanWarTrophies': 10,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 511,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 24},
#   {'tag': '#R2LQ09GG',
#    'name': 'Погремульки',
#    'type': 'open',
#    'badgeId': 16000171,
#    'clanScore': 49496,
#    'clanWarTrophies': 283,
#    'location': {'id': 57000193,
#     'name': 'Russia',
#     'isCountry': True,
#     'countryCode': 'RU'},
#    'requiredTrophies': 3000,
#    'donationsPerWeek': 930,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 24},
#   {'tag': '#YQUL0JLP',
#    'name': 'просто клан',
#    'type': 'open',
#    'badgeId': 16000128,
#    'clanScore': 43740,
#    'clanWarTrophies': 1108,
#    'location': {'id': 57000193,
#     'name': 'Russia',
#     'isCountry': True,
#     'countryCode': 'RU'},
#    'requiredTrophies': 5500,
#    'donationsPerWeek': 724,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 21},
#   {'tag': '#RQY2UY0V',
#    'name': 'пупсы',
#    'type': 'open',
#    'badgeId': 16000129,
#    'clanScore': 40063,
#    'clanWarTrophies': 160,
#    'location': {'id': 57000193,
#     'name': 'Russia',
#     'isCountry': True,
#     'countryCode': 'RU'},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 544,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#QUU9JGJP',
#    'name': 'рваныетрусы24',
#    'type': 'open',
#    'badgeId': 16000139,
#    'clanScore': 50544,
#    'clanWarTrophies': 280,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 300,
#    'donationsPerWeek': 761,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 22},
#   {'tag': '#R8LLGJ92',
#    'name': 'свага тут?',
#    'type': 'open',
#    'badgeId': 16000167,
#    'clanScore': 50711,
#    'clanWarTrophies': 180,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 4000,
#    'donationsPerWeek': 1270,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#R2JQR20Q',
#    'name': 'СКУФЫ 4В',
#    'type': 'open',
#    'badgeId': 16000154,
#    'clanScore': 43715,
#    'clanWarTrophies': 290,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 663,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#R8QQVRQY',
#    'name': 'супный день',
#    'type': 'open',
#    'badgeId': 16000029,
#    'clanScore': 36647,
#    'clanWarTrophies': 80,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 996,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 23},
#   {'tag': '#GUPGPPPU',
#    'name': 'челиксы',
#    'type': 'open',
#    'badgeId': 16000125,
#    'clanScore': 51650,
#    'clanWarTrophies': 379,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 2000,
#    'donationsPerWeek': 496,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 22},
#   {'tag': '#JP02GP0',
#    'name': 'الاصدقاء',
#    'type': 'inviteOnly',
#    'badgeId': 16000031,
#    'clanScore': 57769,
#    'clanWarTrophies': 2040,
#    'location': {'id': 57000077,
#     'name': 'Egypt',
#     'isCountry': True,
#     'countryCode': 'EG'},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 809,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 23},
#   {'tag': '#PQ88L2RP',
#    'name': 'شباب حمص',
#    'type': 'open',
#    'badgeId': 16000139,
#    'clanScore': 59239,
#    'clanWarTrophies': 1927,
#    'location': {'id': 57000000, 'name': 'Europe', 'isCountry': False},
#    'requiredTrophies': 2300,
#    'donationsPerWeek': 1086,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 29},
#   {'tag': '#GJPQJYVR',
#    'name': 'قلب سیاه',
#    'type': 'open',
#    'badgeId': 16000026,
#    'clanScore': 62608,
#    'clanWarTrophies': 2420,
#    'location': {'id': 57000003, 'name': 'Asia', 'isCountry': False},
#    'requiredTrophies': 8000,
#    'donationsPerWeek': 3439,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 26},
#   {'tag': '#RY08JYY8',
#    'name': '‧₊˚૮꒰˵•ᵜ•˵꒱ა‧₊˚',
#    'type': 'open',
#    'badgeId': 16000029,
#    'clanScore': 46580,
#    'clanWarTrophies': 270,
#    'location': {'id': 57000001, 'name': 'North America', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 496,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 22},
#   {'tag': '#QCYRUYLG',
#    'name': '♤campeones♤',
#    'type': 'open',
#    'badgeId': 16000024,
#    'clanScore': 35218,
#    'clanWarTrophies': 170,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 868,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 21},
#   {'tag': '#R2VY0UJL',
#    'name': '✨hesitation✨',
#    'type': 'open',
#    'badgeId': 16000031,
#    'clanScore': 54154,
#    'clanWarTrophies': 670,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 593,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 22},
#   {'tag': '#R88G2VY0',
#    'name': '✰THE PRODIGIOS✰',
#    'type': 'open',
#    'badgeId': 16000144,
#    'clanScore': 51541,
#    'clanWarTrophies': 390,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 300,
#    'donationsPerWeek': 700,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 22},
#   {'tag': '#Q822LJP0',
#    'name': '大的 ÉLITES 世界',
#    'type': 'open',
#    'badgeId': 16000044,
#    'clanScore': 55039,
#    'clanWarTrophies': 1433,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 1106,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 22},
#   {'tag': '#L2GRGYC8',
#    'name': '種FUZ種',
#    'type': 'open',
#    'badgeId': 16000131,
#    'clanScore': 47209,
#    'clanWarTrophies': 1417,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 2000,
#    'donationsPerWeek': 893,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 24},
#   {'tag': '#RQCRQ9QC',
#    'name': '노담패밀리',
#    'type': 'open',
#    'badgeId': 16000024,
#    'clanScore': 50079,
#    'clanWarTrophies': 0,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 414,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#RP8YCQL0',
#    'name': '눈높이',
#    'type': 'open',
#    'badgeId': 16000029,
#    'clanScore': 54306,
#    'clanWarTrophies': 320,
#    'location': {'id': 57000216,
#     'name': 'South Korea',
#     'isCountry': True,
#     'countryCode': 'KR'},
#    'requiredTrophies': 8500,
#    'donationsPerWeek': 793,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 23},
#   {'tag': '#GLGCP028',
#    'name': '대미',
#    'type': 'inviteOnly',
#    'badgeId': 16000127,
#    'clanScore': 61905,
#    'clanWarTrophies': 260,
#    'location': {'id': 57000216,
#     'name': 'South Korea',
#     'isCountry': True,
#     'countryCode': 'KR'},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 1398,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 25},
#   {'tag': '#RYG9P90V',
#    'name': '동지고등학',
#    'type': 'inviteOnly',
#    'badgeId': 16000126,
#    'clanScore': 53194,
#    'clanWarTrophies': 10,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 1490,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 23},
#   {'tag': '#R8GQCUCR',
#    'name': '두호고',
#    'type': 'open',
#    'badgeId': 16000109,
#    'clanScore': 52501,
#    'clanWarTrophies': 94,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 555,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 25},
#   {'tag': '#RPPVJP2J',
#    'name': '매곡뷴신',
#    'type': 'open',
#    'badgeId': 16000160,
#    'clanScore': 46669,
#    'clanWarTrophies': 0,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 518,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#R2GPCLV0',
#    'name': '미리벌중',
#    'type': 'inviteOnly',
#    'badgeId': 16000139,
#    'clanScore': 44130,
#    'clanWarTrophies': 160,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 1101,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 21},
#   {'tag': '#GGRCVYG0',
#    'name': '벵벵',
#    'type': 'open',
#    'badgeId': 16000131,
#    'clanScore': 37955,
#    'clanWarTrophies': 423,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 817,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#RQJ92PP0',
#    'name': '아이! 깨끗해',
#    'type': 'open',
#    'badgeId': 16000021,
#    'clanScore': 48932,
#    'clanWarTrophies': 10,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 1463,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 23},
#   {'tag': '#RY0YPLCL',
#    'name': '아처퀸 발가락',
#    'type': 'open',
#    'badgeId': 16000128,
#    'clanScore': 43547,
#    'clanWarTrophies': 0,
#    'location': {'id': 57000216,
#     'name': 'South Korea',
#     'isCountry': True,
#     'countryCode': 'KR'},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 356,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 23},
#   {'tag': '#QCU22C0U',
#    'name': '여드름맨혜성',
#    'type': 'open',
#    'badgeId': 16000171,
#    'clanScore': 45065,
#    'clanWarTrophies': 0,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 745,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#R8V9LVLJ',
#    'name': '염광고등학교07모임',
#    'type': 'open',
#    'badgeId': 16000163,
#    'clanScore': 59570,
#    'clanWarTrophies': 0,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 1403,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 26},
#   {'tag': '#R8JJQJ8R',
#    'name': '용제',
#    'type': 'open',
#    'badgeId': 16000132,
#    'clanScore': 50861,
#    'clanWarTrophies': 0,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 606,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 23},
#   {'tag': '#QJQCPQ0P',
#    'name': '응아니야fc',
#    'type': 'inviteOnly',
#    'badgeId': 16000080,
#    'clanScore': 22819,
#    'clanWarTrophies': 145,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 265,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 20},
#   {'tag': '#QCYCY8JP',
#    'name': '정발11반',
#    'type': 'open',
#    'badgeId': 16000023,
#    'clanScore': 53939,
#    'clanWarTrophies': 0,
#    'location': {'id': 57000003, 'name': 'Asia', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 1033,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 27},
#   {'tag': '#R8C8ULPP',
#    'name': '착한성록설인',
#    'type': 'open',
#    'badgeId': 16000128,
#    'clanScore': 42647,
#    'clanWarTrophies': 150,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 390,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 21},
#   {'tag': '#R8L00JYL',
#    'name': '향호소년단',
#    'type': 'open',
#    'badgeId': 16000054,
#    'clanScore': 55461,
#    'clanWarTrophies': 50,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 1209,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 22},
#   {'tag': '#RPJ0ULV9',
#    'name': '현대공고',
#    'type': 'open',
#    'badgeId': 16000054,
#    'clanScore': 51345,
#    'clanWarTrophies': 251,
#    'location': {'id': 57000006, 'name': 'International', 'isCountry': False},
#    'requiredTrophies': 0,
#    'donationsPerWeek': 1000,
#    'clanChestLevel': 1,
#    'clanChestMaxLevel': 0,
#    'members': 24}],
#  'paging': {'cursors': {}}}

# %%
my_id = "ULCYC0UU"
battles = get_player_battles(my_id, key)
battles.head(3)
# Out:
#              battleTime    battleType          battleMode     arena  \
# 0  20250508T032734.000Z  pathOfLegend  Ranked1v1_NewArena  54000114
# 1  20250508T030738.000Z  pathOfLegend  Ranked1v1_NewArena  54000114
# 2  20250508T030326.000Z  pathOfLegend  Ranked1v1_NewArena  54000114
#
#         winner      loser  winner_card_1_id  winner_card_1_level  \
# 0   #Q0UVVYLUC  #ULCYC0UU          26000047                   11
# 1  #2002U9P0LC  #ULCYC0UU          26000024                   11
# 2   #P8PRV2UGC  #ULCYC0UU          26000036                    9
#
#    winner_card_2_id  winner_card_2_level  ...  loser_card_5_id  \
# 0          26000064                   11  ...         26000021
# 1          26000064                   11  ...         26000021
# 2          28000008                   11  ...         26000021
#
#    loser_card_5_level  loser_card_6_id  loser_card_6_level  loser_card_7_id  \
# 0                   9         26000041                  11         27000006
# 1                   9         26000041                  11         27000006
# 2                   9         26000041                  11         27000006
#
#    loser_card_7_level  loser_card_8_id  loser_card_8_level  \
# 0                  11         26000052                   9
# 1                  11         26000052                   9
# 2                  11         26000052                   9
#
#    loser_tower_card_id  loser_tower_card_level
# 0            159000000                      11
# 1            159000000                      11
# 2            159000000                      11
#
# [3 rows x 42 columns]

# %%
fs = 'https://api.clashroyale.com/v1/cards'
y = call_api(fs, key).json()

# %%
slice_num = 9

# %%
clans = read_clans_range(start=slice_num*100, end=slice_num*100+100)
df = get_full(file_name = f'clash_battles_{slice_num*100}_{slice_num*100 + 100}', num_clans=100, key=key, clans_list=clans, max_workers = 8)
# Out:
# Retrieved 60 clans
# Retrieved 2994 players
# Saved final df to clash_battles_900_1000.csv.csv
# Done!

# %%
clanstest = get_clans_file(limit=100, minmembers=40, maxmembers=45, minscore=1000, key=key, max_clans=3000, output_file="clans_list_40_45.txt")
# Out:
# Retrieved 100 total clans so far...
# Retrieved 200 total clans so far...
# Retrieved 300 total clans so far...
# Retrieved 400 total clans so far...
# Retrieved 500 total clans so far...
# Retrieved 600 total clans so far...
# Retrieved 700 total clans so far...
# Retrieved 800 total clans so far...
# Retrieved 900 total clans so far...
# Reached the last page.
# Saved 960 clans to clans_list_40_45.txt
